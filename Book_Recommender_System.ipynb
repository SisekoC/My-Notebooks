# %% [markdown]
# <a href="https://colab.research.google.com/github/SisekoC/OpenCV/blob/main/Book_Recommender_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Importing Required Libraries

# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import pandas as pd

# %% [markdown]
# # 2. Data Ingestion

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !kaggle datasets download -d ruchi798/bookcrossing-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ruchi798/bookcrossing-dataset
# License(s): CC0-1.0
# Downloading bookcrossing-dataset.zip to /content
#  64% 49.0M/76.1M [00:00<00:00, 82.1MB/s]
# 100% 76.1M/76.1M [00:00<00:00, 105MB/s]

# %%
# !unzip bookcrossing-dataset
# Out:
# Archive:  bookcrossing-dataset.zip
#   inflating: Book reviews/Book reviews/BX-Book-Ratings.csv
#   inflating: Book reviews/Book reviews/BX-Users.csv
#   inflating: Book reviews/Book reviews/BX_Books.csv
#   inflating: Books Data with Category Language and Summary/Preprocessed_data.csv

# %%
books = pd.read_csv('/content/Book reviews/Book reviews/BX-Book-Ratings.csv', sep=";", encoding='latin-1')
users = pd.read_csv('/content/Book reviews/Book reviews/BX-Users.csv', sep=";", encoding='latin-1')
ratings = pd.read_csv('/content/Book reviews/Book reviews/BX_Books.csv', sep=";", encoding='latin-1')

# %% [markdown]
# # 3. Data Exploration

# %%
print("Books Dataset: ",books.shape)
print("Users Dataset: ",users.shape)
print("Ratings Dataset: ",ratings.shape)
# Out:
# Books Dataset:  (1149780, 3)
# Users Dataset:  (278858, 3)
# Ratings Dataset:  (271379, 8)

# %%
print("Books Dataset: ",books.columns)
print("\nUsers Dataset: ",users.columns)
print("\nRatings Dataset: ",ratings.columns)
# Out:
# Books Dataset:  Index(['User-ID', 'ISBN', 'Book-Rating'], dtype='object')
#
# Users Dataset:  Index(['User-ID', 'Location', 'Age'], dtype='object')
#
# Ratings Dataset:  Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books.rename(columns={"Book-Title":'Title',
                      'Book-Author':'Author',
                     "Year-Of-Publication":'Year',
                     "Image-URL-L":"URL"},inplace=True)

ratings.rename(columns={"Book-Rating": "Ratings"}, inplace=True)

# %%
books.head(2)
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5

# %%
users.head(2)
# Out:
#    User-ID                   Location   Age
# 0        1         nyc, new york, usa   NaN
# 1        2  stockton, california, usa  18.0

# %%
ratings.head(2)
# Out:
#          ISBN           Book-Title           Book-Author  Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                 2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                 2001
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...

# %%
books = books[['ISBN']]

# %%
books.head()
# Out:
#          ISBN
# 0  034545104X
# 1  0155061224
# 2  0446520802
# 3  052165615X
# 4  0521795028

# %% [markdown]
# # 4. Data Pre-processing

# %%
ratings['Book-Author'].value_counts()
# Out:
# Book-Author
# Agatha Christie         632
# William Shakespeare     567
# Stephen King            524
# Ann M. Martin           423
# Carolyn Keene           373
#                        ...
# Emily Pearl Kingsley      1
# Jean Cassels              1
# Bernice Meyers            1
# Mark A. Taylor            1
# Christopher  Biffle       1
# Name: count, Length: 102027, dtype: int64

# %%
x = ratings['Book-Author'].value_counts() > 200
x[x].shape
# Out:
# (20,)

# %%
y= x[x].index

# %%
ratings = ratings[ratings['Book-Author'].isin(y)]

# %%
ratings.shape
# Out:
# (6457, 8)

# %%
ratings_with_books = ratings.merge(books, on='ISBN')

# %%
ratings_with_books.head()
# Out:
#          ISBN           Book-Title         Book-Author  Year-Of-Publication  \
# 0  055321215X  Pride and Prejudice         Jane Austen                 1983
# 1  055321215X  Pride and Prejudice         Jane Austen                 1983
# 2  055321215X  Pride and Prejudice         Jane Austen                 1983
# 3  0671888587   I'll Be Seeing You  Mary Higgins Clark                 1994
# 4  0671888587   I'll Be Seeing You  Mary Higgins Clark                 1994
#
#   Publisher                                        Image-URL-S  \
# 0    Bantam  http://images.amazon.com/images/P/055321215X.0...
# 1    Bantam  http://images.amazon.com/images/P/055321215X.0...
# 2    Bantam  http://images.amazon.com/images/P/055321215X.0...
# 3    Pocket  http://images.amazon.com/images/P/0671888587.0...
# 4    Pocket  http://images.amazon.com/images/P/0671888587.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/055321215X.0...
# 1  http://images.amazon.com/images/P/055321215X.0...
# 2  http://images.amazon.com/images/P/055321215X.0...
# 3  http://images.amazon.com/images/P/0671888587.0...
# 4  http://images.amazon.com/images/P/0671888587.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/055321215X.0...
# 1  http://images.amazon.com/images/P/055321215X.0...
# 2  http://images.amazon.com/images/P/055321215X.0...
# 3  http://images.amazon.com/images/P/0671888587.0...
# 4  http://images.amazon.com/images/P/0671888587.0...

# %%
ratings_with_books.shape
# Out:
# (45236, 8)

# %%
number_rating = ratings_with_books.groupby('Book-Title')['ISBN'].count().reset_index()

# %%
number_rating.head()
# Out:
#                                           Book-Title  ISBN
# 0   Goosebumps Monster Edition 1: Welcome to Dead...     9
# 1   Little Comic Shop of Horrors (Give Yourself G...     4
# 2   The Secret of the Old Clock (Nancy Drew, Book 1)     3
# 3                                       'Salem's Lot    47
# 4                                  10 LITTLE INDIANS     1

# %%
number_rating.rename(columns={'Ratings':'No. of Ratings'},inplace=True)

# %%
number_rating.head()
# Out:
#                                           Book-Title  ISBN
# 0   Goosebumps Monster Edition 1: Welcome to Dead...     9
# 1   Little Comic Shop of Horrors (Give Yourself G...     4
# 2   The Secret of the Old Clock (Nancy Drew, Book 1)     3
# 3                                       'Salem's Lot    47
# 4                                  10 LITTLE INDIANS     1

# %%
final_rating = ratings_with_books.merge(number_rating, on='Book-Title')

# %%
final_rating.head()
# Out:
#        ISBN_x           Book-Title  Book-Author  Year-Of-Publication  \
# 0  055321215X  Pride and Prejudice  Jane Austen                 1983
# 1  055321215X  Pride and Prejudice  Jane Austen                 1983
# 2  055321215X  Pride and Prejudice  Jane Austen                 1983
# 3  0553213105  Pride and Prejudice  Jane Austen                 1981
# 4  0553213105  Pride and Prejudice  Jane Austen                 1981
#
#   Publisher                                        Image-URL-S  \
# 0    Bantam  http://images.amazon.com/images/P/055321215X.0...
# 1    Bantam  http://images.amazon.com/images/P/055321215X.0...
# 2    Bantam  http://images.amazon.com/images/P/055321215X.0...
# 3    Bantam  http://images.amazon.com/images/P/0553213105.0...
# 4    Bantam  http://images.amazon.com/images/P/0553213105.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/055321215X.0...
# 1  http://images.amazon.com/images/P/055321215X.0...
# 2  http://images.amazon.com/images/P/055321215X.0...
# 3  http://images.amazon.com/images/P/0553213105.0...
# 4  http://images.amazon.com/images/P/0553213105.0...
#
#                                          Image-URL-L  ISBN_y
# 0  http://images.amazon.com/images/P/055321215X.0...     182
# 1  http://images.amazon.com/images/P/055321215X.0...     182
# 2  http://images.amazon.com/images/P/055321215X.0...     182
# 3  http://images.amazon.com/images/P/0553213105.0...     182
# 4  http://images.amazon.com/images/P/0553213105.0...     182

# %%
final_rating.shape
# Out:
# (45236, 9)

# %%
final_rating.rename(columns={'ISBN_y':'No. of Ratings'},inplace=True)

# %%
final_rating = final_rating[final_rating['No. of Ratings'] >= 50]

# %%
final_rating.head()
# Out:
#        ISBN_x           Book-Title  Book-Author  Year-Of-Publication  \
# 0  055321215X  Pride and Prejudice  Jane Austen                 1983
# 1  055321215X  Pride and Prejudice  Jane Austen                 1983
# 2  055321215X  Pride and Prejudice  Jane Austen                 1983
# 3  0553213105  Pride and Prejudice  Jane Austen                 1981
# 4  0553213105  Pride and Prejudice  Jane Austen                 1981
#
#   Publisher                                        Image-URL-S  \
# 0    Bantam  http://images.amazon.com/images/P/055321215X.0...
# 1    Bantam  http://images.amazon.com/images/P/055321215X.0...
# 2    Bantam  http://images.amazon.com/images/P/055321215X.0...
# 3    Bantam  http://images.amazon.com/images/P/0553213105.0...
# 4    Bantam  http://images.amazon.com/images/P/0553213105.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/055321215X.0...
# 1  http://images.amazon.com/images/P/055321215X.0...
# 2  http://images.amazon.com/images/P/055321215X.0...
# 3  http://images.amazon.com/images/P/0553213105.0...
# 4  http://images.amazon.com/images/P/0553213105.0...
#
#                                          Image-URL-L  No. of Ratings
# 0  http://images.amazon.com/images/P/055321215X.0...             182
# 1  http://images.amazon.com/images/P/055321215X.0...             182
# 2  http://images.amazon.com/images/P/055321215X.0...             182
# 3  http://images.amazon.com/images/P/0553213105.0...             182
# 4  http://images.amazon.com/images/P/0553213105.0...             182

# %%
final_rating.shape
# Out:
# (20781, 9)

# %%
book_pivot = final_rating.pivot_table(columns='ISBN_x', index='Book-Title', values= 'No. of Ratings')

# %%
book_pivot
# Out:
# ISBN_x                                            0006170056  0060467215  \
# Book-Title
# A Cry In The Night                                       NaN         NaN
# A Spell for Chameleon (Xanth Novels (Paperback))         NaN         NaN
# Adventures of Huckleberry Finn                           NaN        81.0
# All Around the Town                                      NaN         NaN
# All Through the Night (Holiday Classics)                 NaN         NaN
# ...                                                      ...         ...
# Where Are the Children?                                  NaN         NaN
# While My Pretty One Sleeps                               NaN         NaN
# Wizard and Glass (The Dark Tower, Book 4)                NaN         NaN
# YOU BELONG TO ME                                         NaN         NaN
# You Belong To Me                                         NaN         NaN
#
# ISBN_x                                            0060806125  0061003263  \
# Book-Title
# A Cry In The Night                                       NaN         NaN
# A Spell for Chameleon (Xanth Novels (Paperback))         NaN         NaN
# Adventures of Huckleberry Finn                          81.0         NaN
# All Around the Town                                      NaN         NaN
# All Through the Night (Holiday Classics)                 NaN         NaN
# ...                                                      ...         ...
# Where Are the Children?                                  NaN         NaN
# While My Pretty One Sleeps                               NaN         NaN
# Wizard and Glass (The Dark Tower, Book 4)                NaN         NaN
# YOU BELONG TO ME                                         NaN         NaN
# You Belong To Me                                         NaN         NaN
#
# ISBN_x                                            0061020702  0061020710  \
# Book-Title
# A Cry In The Night                                       NaN         NaN
# A Spell for Chameleon (Xanth Novels (Paperback))         NaN         NaN
# Adventures of Huckleberry Finn                           NaN         NaN
# All Around the Town                                      NaN         NaN
# All Through the Night (Holiday Classics)                 NaN         NaN
# ...                                                      ...         ...
# Where Are the Children?                                  NaN         NaN
# While My Pretty One Sleeps                               NaN         NaN
# Wizard and Glass (The Dark Tower, Book 4)                NaN         NaN
# YOU BELONG TO ME                                         NaN         NaN
# You Belong To Me                                         NaN         NaN
#
# ISBN_x                                            0099928205  0140059342  \
# Book-Title
# A Cry In The Night                                       NaN         NaN
# A Spell for Chameleon (Xanth Novels (Paperback))         NaN         NaN
# Adventures of Huckleberry Finn                           NaN         NaN
# All Around the Town                                      NaN         NaN
# All Through the Night (Holiday Classics)                 NaN         NaN
# ...                                                      ...         ...
# Where Are the Children?                                  NaN         NaN
# While My Pretty One Sleeps                               NaN         NaN
# Wizard and Glass (The Dark Tower, Book 4)                NaN         NaN
# YOU BELONG TO ME                                         NaN         NaN
# You Belong To Me                                         NaN         NaN
#
# ISBN_x                                            0140238212  0140239316  ...  \
# Book-Title                                                                ...
# A Cry In The Night                                       NaN         NaN  ...
# A Spell for Chameleon (Xanth Novels (Paperback))         NaN         NaN  ...
# Adventures of Huckleberry Finn                           NaN         NaN  ...
# All Around the Town                                      NaN         NaN  ...
# All Through the Night (Holiday Classics)                 NaN         NaN  ...
# ...                                                      ...         ...  ...
# Where Are the Children?                                  NaN         NaN  ...
# While My Pretty One Sleeps                               NaN         NaN  ...
# Wizard and Glass (The Dark Tower, Book 4)                NaN         NaN  ...
# YOU BELONG TO ME                                         NaN         NaN  ...
# You Belong To Me                                         NaN         NaN  ...
#
# ISBN_x                                            8437610974  8878242357  \
# Book-Title
# A Cry In The Night                                       NaN         NaN
# A Spell for Chameleon (Xanth Novels (Paperback))         NaN         NaN
# Adventures of Huckleberry Finn                           NaN         NaN
# All Around the Town                                      NaN         NaN
# All Through the Night (Holiday Classics)                 NaN         NaN
# ...                                                      ...         ...
# Where Are the Children?                                  NaN         NaN
# While My Pretty One Sleeps                               NaN         NaN
# Wizard and Glass (The Dark Tower, Book 4)                NaN         NaN
# YOU BELONG TO ME                                         NaN         NaN
# You Belong To Me                                         NaN         NaN
#
# ISBN_x                                            9504905501  B00001IVC7  \
# Book-Title
# A Cry In The Night                                       NaN         NaN
# A Spell for Chameleon (Xanth Novels (Paperback))         NaN         NaN
# Adventures of Huckleberry Finn                           NaN         NaN
# All Around the Town                                      NaN         NaN
# All Through the Night (Holiday Classics)                 NaN         NaN
# ...                                                      ...         ...
# Where Are the Children?                                  NaN         NaN
# While My Pretty One Sleeps                               NaN         NaN
# Wizard and Glass (The Dark Tower, Book 4)                NaN         NaN
# YOU BELONG TO ME                                         NaN         NaN
# You Belong To Me                                         NaN         NaN
#
# ISBN_x                                            B00005BBW4  B00005NCS7  \
# Book-Title
# A Cry In The Night                                       NaN         NaN
# A Spell for Chameleon (Xanth Novels (Paperback))         NaN         NaN
# Adventures of Huckleberry Finn                           NaN         NaN
# All Around the Town                                      NaN         NaN
# All Through the Night (Holiday Classics)                 NaN         NaN
# ...                                                      ...         ...
# Where Are the Children?                                  NaN         NaN
# While My Pretty One Sleeps                               NaN         NaN
# Wizard and Glass (The Dark Tower, Book 4)                NaN         NaN
# YOU BELONG TO ME                                         NaN         NaN
# You Belong To Me                                         NaN         NaN
#
# ISBN_x                                            B00005Q8OL  B00007CWQC  \
# Book-Title
# A Cry In The Night                                       NaN         NaN
# A Spell for Chameleon (Xanth Novels (Paperback))         NaN         NaN
# Adventures of Huckleberry Finn                           NaN         NaN
# All Around the Town                                      NaN         NaN
# All Through the Night (Holiday Classics)                 NaN         NaN
# ...                                                      ...         ...
# Where Are the Children?                                  NaN         NaN
# While My Pretty One Sleeps                               NaN         NaN
# Wizard and Glass (The Dark Tower, Book 4)                NaN         NaN
# YOU BELONG TO ME                                         NaN         NaN
# You Belong To Me                                         NaN         NaN
#
# ISBN_x                                            B0000E63CJ  B0000T6KHI
# Book-Title
# A Cry In The Night                                       NaN         NaN
# A Spell for Chameleon (Xanth Novels (Paperback))         NaN         NaN
# Adventures of Huckleberry Finn                           NaN         NaN
# All Around the Town                                      NaN         NaN
# All Through the Night (Holiday Classics)                 NaN         NaN
# ...                                                      ...         ...
# Where Are the Children?                                  NaN         NaN
# While My Pretty One Sleeps                               NaN         NaN
# Wizard and Glass (The Dark Tower, Book 4)                NaN         NaN
# YOU BELONG TO ME                                         NaN         NaN
# You Belong To Me                                         NaN         NaN
#
# [174 rows x 510 columns]

# %%
book_pivot.shape
# Out:
# (174, 510)

# %%
book_pivot.fillna(0, inplace=True)

# %%
book_pivot
# Out:
# ISBN_x                                            0006170056  0060467215  \
# Book-Title
# A Cry In The Night                                       0.0         0.0
# A Spell for Chameleon (Xanth Novels (Paperback))         0.0         0.0
# Adventures of Huckleberry Finn                           0.0        81.0
# All Around the Town                                      0.0         0.0
# All Through the Night (Holiday Classics)                 0.0         0.0
# ...                                                      ...         ...
# Where Are the Children?                                  0.0         0.0
# While My Pretty One Sleeps                               0.0         0.0
# Wizard and Glass (The Dark Tower, Book 4)                0.0         0.0
# YOU BELONG TO ME                                         0.0         0.0
# You Belong To Me                                         0.0         0.0
#
# ISBN_x                                            0060806125  0061003263  \
# Book-Title
# A Cry In The Night                                       0.0         0.0
# A Spell for Chameleon (Xanth Novels (Paperback))         0.0         0.0
# Adventures of Huckleberry Finn                          81.0         0.0
# All Around the Town                                      0.0         0.0
# All Through the Night (Holiday Classics)                 0.0         0.0
# ...                                                      ...         ...
# Where Are the Children?                                  0.0         0.0
# While My Pretty One Sleeps                               0.0         0.0
# Wizard and Glass (The Dark Tower, Book 4)                0.0         0.0
# YOU BELONG TO ME                                         0.0         0.0
# You Belong To Me                                         0.0         0.0
#
# ISBN_x                                            0061020702  0061020710  \
# Book-Title
# A Cry In The Night                                       0.0         0.0
# A Spell for Chameleon (Xanth Novels (Paperback))         0.0         0.0
# Adventures of Huckleberry Finn                           0.0         0.0
# All Around the Town                                      0.0         0.0
# All Through the Night (Holiday Classics)                 0.0         0.0
# ...                                                      ...         ...
# Where Are the Children?                                  0.0         0.0
# While My Pretty One Sleeps                               0.0         0.0
# Wizard and Glass (The Dark Tower, Book 4)                0.0         0.0
# YOU BELONG TO ME                                         0.0         0.0
# You Belong To Me                                         0.0         0.0
#
# ISBN_x                                            0099928205  0140059342  \
# Book-Title
# A Cry In The Night                                       0.0         0.0
# A Spell for Chameleon (Xanth Novels (Paperback))         0.0         0.0
# Adventures of Huckleberry Finn                           0.0         0.0
# All Around the Town                                      0.0         0.0
# All Through the Night (Holiday Classics)                 0.0         0.0
# ...                                                      ...         ...
# Where Are the Children?                                  0.0         0.0
# While My Pretty One Sleeps                               0.0         0.0
# Wizard and Glass (The Dark Tower, Book 4)                0.0         0.0
# YOU BELONG TO ME                                         0.0         0.0
# You Belong To Me                                         0.0         0.0
#
# ISBN_x                                            0140238212  0140239316  ...  \
# Book-Title                                                                ...
# A Cry In The Night                                       0.0         0.0  ...
# A Spell for Chameleon (Xanth Novels (Paperback))         0.0         0.0  ...
# Adventures of Huckleberry Finn                           0.0         0.0  ...
# All Around the Town                                      0.0         0.0  ...
# All Through the Night (Holiday Classics)                 0.0         0.0  ...
# ...                                                      ...         ...  ...
# Where Are the Children?                                  0.0         0.0  ...
# While My Pretty One Sleeps                               0.0         0.0  ...
# Wizard and Glass (The Dark Tower, Book 4)                0.0         0.0  ...
# YOU BELONG TO ME                                         0.0         0.0  ...
# You Belong To Me                                         0.0         0.0  ...
#
# ISBN_x                                            8437610974  8878242357  \
# Book-Title
# A Cry In The Night                                       0.0         0.0
# A Spell for Chameleon (Xanth Novels (Paperback))         0.0         0.0
# Adventures of Huckleberry Finn                           0.0         0.0
# All Around the Town                                      0.0         0.0
# All Through the Night (Holiday Classics)                 0.0         0.0
# ...                                                      ...         ...
# Where Are the Children?                                  0.0         0.0
# While My Pretty One Sleeps                               0.0         0.0
# Wizard and Glass (The Dark Tower, Book 4)                0.0         0.0
# YOU BELONG TO ME                                         0.0         0.0
# You Belong To Me                                         0.0         0.0
#
# ISBN_x                                            9504905501  B00001IVC7  \
# Book-Title
# A Cry In The Night                                       0.0         0.0
# A Spell for Chameleon (Xanth Novels (Paperback))         0.0         0.0
# Adventures of Huckleberry Finn                           0.0         0.0
# All Around the Town                                      0.0         0.0
# All Through the Night (Holiday Classics)                 0.0         0.0
# ...                                                      ...         ...
# Where Are the Children?                                  0.0         0.0
# While My Pretty One Sleeps                               0.0         0.0
# Wizard and Glass (The Dark Tower, Book 4)                0.0         0.0
# YOU BELONG TO ME                                         0.0         0.0
# You Belong To Me                                         0.0         0.0
#
# ISBN_x                                            B00005BBW4  B00005NCS7  \
# Book-Title
# A Cry In The Night                                       0.0         0.0
# A Spell for Chameleon (Xanth Novels (Paperback))         0.0         0.0
# Adventures of Huckleberry Finn                           0.0         0.0
# All Around the Town                                      0.0         0.0
# All Through the Night (Holiday Classics)                 0.0         0.0
# ...                                                      ...         ...
# Where Are the Children?                                  0.0         0.0
# While My Pretty One Sleeps                               0.0         0.0
# Wizard and Glass (The Dark Tower, Book 4)                0.0         0.0
# YOU BELONG TO ME                                         0.0         0.0
# You Belong To Me                                         0.0         0.0
#
# ISBN_x                                            B00005Q8OL  B00007CWQC  \
# Book-Title
# A Cry In The Night                                       0.0         0.0
# A Spell for Chameleon (Xanth Novels (Paperback))         0.0         0.0
# Adventures of Huckleberry Finn                           0.0         0.0
# All Around the Town                                      0.0         0.0
# All Through the Night (Holiday Classics)                 0.0         0.0
# ...                                                      ...         ...
# Where Are the Children?                                  0.0         0.0
# While My Pretty One Sleeps                               0.0         0.0
# Wizard and Glass (The Dark Tower, Book 4)                0.0         0.0
# YOU BELONG TO ME                                         0.0         0.0
# You Belong To Me                                         0.0         0.0
#
# ISBN_x                                            B0000E63CJ  B0000T6KHI
# Book-Title
# A Cry In The Night                                       0.0         0.0
# A Spell for Chameleon (Xanth Novels (Paperback))         0.0         0.0
# Adventures of Huckleberry Finn                           0.0         0.0
# All Around the Town                                      0.0         0.0
# All Through the Night (Holiday Classics)                 0.0         0.0
# ...                                                      ...         ...
# Where Are the Children?                                  0.0         0.0
# While My Pretty One Sleeps                               0.0         0.0
# Wizard and Glass (The Dark Tower, Book 4)                0.0         0.0
# YOU BELONG TO ME                                         0.0         0.0
# You Belong To Me                                         0.0         0.0
#
# [174 rows x 510 columns]

# %% [markdown]
# # Training Model

# %%
from scipy.sparse import csr_matrix
book_sparse = csr_matrix(book_pivot)

book_names = book_pivot.index

# %%
from sklearn.neighbors import NearestNeighbors
model = NearestNeighbors(algorithm= 'brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
print(book_pivot.shape)
# Out:
# (174, 510)

# %%
distances, suggestions = model.kneighbors(book_pivot.iloc[170, :].values.reshape(1, -1), n_neighbors=6)

# %%
distances
# Out:
# array([[  0.        , 197.35754356, 197.35754356, 197.35754356,
#         197.87369709, 197.87369709]])

# %%
suggestions
# Out:
# array([[170, 154,  71,  29,  92,  88]])

# %%
book_pivot.iloc[173,:]
# Out:
# ISBN_x
# 0006170056    0.0
# 0060467215    0.0
# 0060806125    0.0
# 0061003263    0.0
# 0061020702    0.0
#              ...
# B00005NCS7    0.0
# B00005Q8OL    0.0
# B00007CWQC    0.0
# B0000E63CJ    0.0
# B0000T6KHI    0.0
# Name: You Belong To Me, Length: 510, dtype: float64

# %%
for i in range(len(suggestions)):
    print(book_pivot.index[suggestions[i]])
# Out:
# Index(['While My Pretty One Sleeps', 'The Stand: The Complete & Uncut Edition',
#        'Less Of A Stranger (Silhouette Single Title)', 'Dangerous',
#        'On a Pale Horse (Incarnations of Immortality, Bk. 1)',
#        'Night Shield (Intimate Moments, 1027)'],
#       dtype='object', name='Book-Title')

# %%
import pickle
pickle.dump(model,open('Model.pkl','wb'))
pickle.dump(book_names,open('Book_Names.pkl','wb'))
pickle.dump(final_rating,open('Final_Rating.pkl','wb'))
pickle.dump(book_pivot,open('Book_Pivot.pkl','wb'))

# %% [markdown]
# # 5. Model Evaluation

# %%
def recommend_book(book_name):
    if book_name in book_pivot.index:
        book_id = np.where(book_pivot.index == book_name)[0][0]
        distances, suggestions = model.kneighbors(book_pivot.iloc[book_id, :].values.reshape(1, -1), n_neighbors=6)

        for i in range(len(suggestions)):
            print(book_pivot.index[suggestions[i]])
    else:
        print(f"Book '{book_name}' not found in the dataset.")

# Example usage
recommend_book("While My Pretty One Sleeps")
# Out:
# Index(['While My Pretty One Sleeps', 'The Stand: The Complete & Uncut Edition',
#        'Less Of A Stranger (Silhouette Single Title)', 'Dangerous',
#        'On a Pale Horse (Incarnations of Immortality, Bk. 1)',
#        'Night Shield (Intimate Moments, 1027)'],
#       dtype='object', name='Book-Title')
