# %% [markdown]
# <a href="https://colab.research.google.com/github/SisekoC/My-Notebooks/blob/main/FILM_for_video_diffusion_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #FILM for video diffusion models

# %%
# !pip install -q mediapy --quiet
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np
import cv2
from typing import Generator, Iterable, List, Optional
from PIL import Image
import mediapy as media

# %%
model = hub.load('https://tfhub.dev/google/film/1')

# %%
video_file = '/content/Teddy bear dancing is AWESOME.mp4'
cap = cv2.VideoCapture(video_file)
n_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
frames = []

for _ in range(n_frames):
  _, frame = cap.read()
  frames.append(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

cap.release()
frames = np.array(frames)
frames.shape
# Out:
# (215, 854, 480, 3)

# %%
def load_image(img):
  UINT8_MAX_F = float(np.iinfo(np.uint8).max)
  img_numpy = tf.cast(img, dtype=tf.float32).numpy()
  return img_numpy / UINT8_MAX_F

def film(img1, img2):
  time = np.array([0.5], dtype=np.float32)
  input = {
      'time': np.expand_dims(time, axis=0),
      'x0': np.expand_dims(img1, axis=0),
      'x1': np.expand_dims(img2, axis=0)
  }
  mid_frame = model(input)
  return mid_frame['image'][0].numpy()

# %%
img1 = load_image(frames[0])
img2 = load_image(frames[5])

mid_frame = film(img1, img2)

output_frames = [img1, mid_frame, img2]
media.show_images(output_frames, titles=['First input image', 'Generated image', 'Second input image'],
                  height=250)
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><div style="display:flex; align-items:left;">
#       <div style="display:flex; flex-direction:column; align-items:center;">
#       <div>First input image</div><div><img width="141" height="250" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></div></div></div></td><td style="padding:1px;"><div style="display:flex; align-items:left;">
#       <div style="display:flex; flex-direction:column; align-items:center;">
#       <div>Generated image</div><div><img width="141" height="250" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></div></div></div></td><td style="padding:1px;"><div style="display:flex; align-items:left;">
#       <div style="display:flex; flex-direction:column; align-items:center;">
#       <div>Second input image</div><div><img width="141" height="250" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></div></div></div></td></tr></table>

# %%
output_frames = [img1]

for i in range(n_frames - 1):
  img1 = load_image(frames[i])
  img5 = load_image(frames[i + 1])

  img3 = film(img1, img5)
  img2 = film(img1, img3)
  img4 = film(img3, img5)

  output_frames.append(img2)
  output_frames.append(img3)
  output_frames.append(img4)
  output_frames.append(img5)

  print(f'{4 * (i+1)}/{4 * n_frames} frames processed.')

output_frames = np.array(output_frames)
output_frames.shape
# Out:
# 4/860 frames processed.
# 8/860 frames processed.
# 12/860 frames processed.
# 16/860 frames processed.
# 20/860 frames processed.
# 24/860 frames processed.
# 28/860 frames processed.
# 32/860 frames processed.
# 36/860 frames processed.
# 40/860 frames processed.
# 44/860 frames processed.
# 48/860 frames processed.
# 52/860 frames processed.
# 56/860 frames processed.
# 60/860 frames processed.
# 64/860 frames processed.
# 68/860 frames processed.
# 72/860 frames processed.
# 76/860 frames processed.
# 80/860 frames processed.
# 84/860 frames processed.
# 88/860 frames processed.
# 92/860 frames processed.
# 96/860 frames processed.
# 100/860 frames processed.
# 104/860 frames processed.
# 108/860 frames processed.
# 112/860 frames processed.
# 116/860 frames processed.
# 120/860 frames processed.
# 124/860 frames processed.
# 128/860 frames processed.
# 132/860 frames processed.
# 136/860 frames processed.
# 140/860 frames processed.
# 144/860 frames processed.
# 148/860 frames processed.
# 152/860 frames processed.
# 156/860 frames processed.
# 160/860 frames processed.
# 164/860 frames processed.
# 168/860 frames processed.
# 172/860 frames processed.
# 176/860 frames processed.
# 180/860 frames processed.
# 184/860 frames processed.
# 188/860 frames processed.
# 192/860 frames processed.
# 196/860 frames processed.
# 200/860 frames processed.
# 204/860 frames processed.
# 208/860 frames processed.
# 212/860 frames processed.
# 216/860 frames processed.
# 220/860 frames processed.
# 224/860 frames processed.
# 228/860 frames processed.
# 232/860 frames processed.
# 236/860 frames processed.
# 240/860 frames processed.
# 244/860 frames processed.
# 248/860 frames processed.
# 252/860 frames processed.
# 256/860 frames processed.
# 260/860 frames processed.
# 264/860 frames processed.
# 268/860 frames processed.
# 272/860 frames processed.
# 276/860 frames processed.
# 280/860 frames processed.
# 284/860 frames processed.
# 288/860 frames processed.
# 292/860 frames processed.
# 296/860 frames processed.
# 300/860 frames processed.
# 304/860 frames processed.
# 308/860 frames processed.
# 312/860 frames processed.
# 316/860 frames processed.
# 320/860 frames processed.
# 324/860 frames processed.
# 328/860 frames processed.
# 332/860 frames processed.
# 336/860 frames processed.
# 340/860 frames processed.
# 344/860 frames processed.
# 348/860 frames processed.
# 352/860 frames processed.
# 356/860 frames processed.
# 360/860 frames processed.
# 364/860 frames processed.
# 368/860 frames processed.
# 372/860 frames processed.
# 376/860 frames processed.
# 380/860 frames processed.
# 384/860 frames processed.
# 388/860 frames processed.
# 392/860 frames processed.
# 396/860 frames processed.
# 400/860 frames processed.
# 404/860 frames processed.
# 408/860 frames processed.
# 412/860 frames processed.
# 416/860 frames processed.
# 420/860 frames processed.
# 424/860 frames processed.
# 428/860 frames processed.
# 432/860 frames processed.
# 436/860 frames processed.
# 440/860 frames processed.
# 444/860 frames processed.
# 448/860 frames processed.
# 452/860 frames processed.
# 456/860 frames processed.
# 460/860 frames processed.
# 464/860 frames processed.
# 468/860 frames processed.
# 472/860 frames processed.
# 476/860 frames processed.
# 480/860 frames processed.
# 484/860 frames processed.
# 488/860 frames processed.
# 492/860 frames processed.
# 496/860 frames processed.
# 500/860 frames processed.
# 504/860 frames processed.
# 508/860 frames processed.
# 512/860 frames processed.
# 516/860 frames processed.
# 520/860 frames processed.
# 524/860 frames processed.
# 528/860 frames processed.
# 532/860 frames processed.
# 536/860 frames processed.
# 540/860 frames processed.
# 544/860 frames processed.
# 548/860 frames processed.
# 552/860 frames processed.
# 556/860 frames processed.
# 560/860 frames processed.
# 564/860 frames processed.
# 568/860 frames processed.
# 572/860 frames processed.
# 576/860 frames processed.
# 580/860 frames processed.
# 584/860 frames processed.
# 588/860 frames processed.
# 592/860 frames processed.
# 596/860 frames processed.
# 600/860 frames processed.
# 604/860 frames processed.
# 608/860 frames processed.
# 612/860 frames processed.
# 616/860 frames processed.
# 620/860 frames processed.
# 624/860 frames processed.
# 628/860 frames processed.
# 632/860 frames processed.
# 636/860 frames processed.
# 640/860 frames processed.
# 644/860 frames processed.
# 648/860 frames processed.
# 652/860 frames processed.
# 656/860 frames processed.
# 660/860 frames processed.
# 664/860 frames processed.
# 668/860 frames processed.
# 672/860 frames processed.
# 676/860 frames processed.
# 680/860 frames processed.
# 684/860 frames processed.
# 688/860 frames processed.
# 692/860 frames processed.
# 696/860 frames processed.
# 700/860 frames processed.
# 704/860 frames processed.
# 708/860 frames processed.
# 712/860 frames processed.
# 716/860 frames processed.
# 720/860 frames processed.
# 724/860 frames processed.
# 728/860 frames processed.
# 732/860 frames processed.
# 736/860 frames processed.
# 740/860 frames processed.
# 744/860 frames processed.
# 748/860 frames processed.
# 752/860 frames processed.
# 756/860 frames processed.
# 760/860 frames processed.
# 764/860 frames processed.
# 768/860 frames processed.
# 772/860 frames processed.
# 776/860 frames processed.
# 780/860 frames processed.
# 784/860 frames processed.
# 788/860 frames processed.
# 792/860 frames processed.
# 796/860 frames processed.
# 800/860 frames processed.
# 804/860 frames processed.
# 808/860 frames processed.
# 812/860 frames processed.
# 816/860 frames processed.
# 820/860 frames processed.
# 824/860 frames processed.
# 828/860 frames processed.
# 832/860 frames processed.
# 836/860 frames processed.
# 840/860 frames processed.
# 844/860 frames processed.
# 848/860 frames processed.
# 852/860 frames processed.
# 856/860 frames processed.
# (857, 854, 480, 3)

# %%
output_filename = 'result.mp4'
fps = 16
resolution = (256, 256)
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
writer = cv2.VideoWriter(output_filename, fourcc, fps, resolution)

for frame in output_frames:
  frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
  frame = (frame * 255).astype(np.uint8)
  writer.write(frame)

writer.release()
