# %% [markdown]
# <a href="https://colab.research.google.com/github/SisekoC/My-Notebooks/blob/main/Clustering_metrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clustering metrics - alternatives to the _elbow method_
# ### Dr. Tirthajyoti Sarkar, Fremont, CA 94536
#
# Clustering is an important part of the machine learning pipeline for business or scientific enterprises utilizing data science. As the name suggests, it helps to identify congregations of closely related (by some measure of distance) data points in a blob of data, which, otherwise, would be difficult to make sense of.
#
# A popular method like k-means clustering does not seem to provide a completely satisfactory answer when we ask the basic question:
# > **"How would we know the actual number of clusters, to begin with?"**
#
# This question is critically important because of the fact that the process of clustering is often a precursor to further processing of the individual cluster data and therefore, the amount of computational resource may depend on this measurement.
#
# In the case of a business analytics problem, repercussion could be worse. Clustering is often done for such analytics with the goal of market segmentation. It is, therefore, easily conceivable that, depending on the number of clusters, appropriate marketing personnel will be allocated to the problem. Consequently, a wrong assessment of the number of clusters can lead to sub-optimum allocation of precious resources.
#
# For the k-means clustering method, the most common approach for answering this question is the so-called elbow method. It involves running the algorithm multiple times over a loop, with an increasing number of cluster choice and then plotting a clustering score as a function of the number of clusters.
#
# In this notebook, we show what metric to use for visualizing and determining an optimal number of clusters much better than the usual practice - elbow method.
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Create synthetic data using Scikit learn `make_blob` method
#
# - Number of features: 4
# - Number of clusters: 5
# - Number of samples: 200

# %%
from sklearn.datasets import make_classification
from sklearn.datasets import make_blobs

# %%
n_features = 4
n_cluster = 5
cluster_std = 1.2
n_samples = 200

# %%
data1 = make_blobs(n_samples=n_samples,n_features=n_features,centers=n_cluster,cluster_std=cluster_std)

# %%
d1 = data1[0]

# %%
df1=pd.DataFrame(data=d1,columns=['Feature_'+str(i) for i in range(1,n_features+1)])
df1.head()
# Out:
#    Feature_1  Feature_2  Feature_3  Feature_4
# 0   0.182011   8.745316   5.143043   8.768226
# 1   1.287319   8.911586   4.035373   8.570773
# 2   1.444564  -0.005299   9.260799   2.057424
# 3   0.930157  -0.828276   8.511081   0.979656
# 4   6.979280   4.035216   2.165716  -3.385878

# %%
from itertools import combinations

# %%
lst_vars=list(combinations(df1.columns,2))

# %%
len(lst_vars)
# Out:
# 6

# %%
plt.figure(figsize=(15,8))
for i in range(1,7):
    plt.subplot(2,3,i)
    dim1=lst_vars[i-1][0]
    dim2=lst_vars[i-1][1]
    plt.scatter(df1[dim1],df1[dim2],c=data1[1],edgecolor='k',s=150)
    plt.xlabel(f"{dim1}",fontsize=13)
    plt.ylabel(f"{dim2}",fontsize=13)

# %% [markdown]
# ### How are the classes separated (boxplots)

# %%
plt.figure(figsize=(16,14))
for i,c in enumerate(df1.columns):
    plt.subplot(3,2,i+1)
    sns.boxplot(y=df1[c],x=data1[1])
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.xlabel("Class",fontsize=15)
    plt.ylabel(c,fontsize=15)
    #plt.show()

# %% [markdown]
# ## k-means clustering

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# ### Unlabled data

# %%
X=df1

# %%
X.head()
# Out:
#    Feature_1  Feature_2  Feature_3  Feature_4
# 0   0.182011   8.745316   5.143043   8.768226
# 1   1.287319   8.911586   4.035373   8.570773
# 2   1.444564  -0.005299   9.260799   2.057424
# 3   0.930157  -0.828276   8.511081   0.979656
# 4   6.979280   4.035216   2.165716  -3.385878

# %%
y=data1[1]

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_scaled=scaler.fit_transform(X)

# %% [markdown]
# ### Metrics

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score,v_measure_score

# %% [markdown]
# ### Running k-means and computing inter-cluster distance score for various *k* values

# %%
km_scores= []
km_silhouette = []
vmeasure_score =[]
db_score = []
for i in range(2,12):
    km = KMeans(n_clusters=i, random_state=0).fit(X_scaled)
    preds = km.predict(X_scaled)

    print("Score for number of cluster(s) {}: {}".format(i,km.score(X_scaled)))
    km_scores.append(-km.score(X_scaled))

    silhouette = silhouette_score(X_scaled,preds)
    km_silhouette.append(silhouette)
    print("Silhouette score for number of cluster(s) {}: {}".format(i,silhouette))

    db = davies_bouldin_score(X_scaled,preds)
    db_score.append(db)
    print("Davies Bouldin score for number of cluster(s) {}: {}".format(i,db))

    v_measure = v_measure_score(y,preds)
    vmeasure_score.append(v_measure)
    print("V-measure score for number of cluster(s) {}: {}".format(i,v_measure))
    print("-"*100)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Score for number of cluster(s) 2: -26.888858618979793
# Silhouette score for number of cluster(s) 2: 0.5714127101555755
# Davies Bouldin score for number of cluster(s) 2: 0.5252825870119116
# V-measure score for number of cluster(s) 2: 0.47435098761403227
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 3: -11.187561237428948
# Silhouette score for number of cluster(s) 3: 0.5949321762774291
# Davies Bouldin score for number of cluster(s) 3: 0.6772787320921719
# V-measure score for number of cluster(s) 3: 0.7918756684685209
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 4: -6.218814013917537
# Silhouette score for number of cluster(s) 4: 0.6510487779359903
# Davies Bouldin score for number of cluster(s) 4: 0.4744548496761557
# V-measure score for number of cluster(s) 4: 0.905746099275519
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 5: -3.2414493555657677
# Silhouette score for number of cluster(s) 5: 0.6685248895947323
# Davies Bouldin score for number of cluster(s) 5: 0.48787116114713935
# V-measure score for number of cluster(s) 5: 1.0
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 6: -2.974713288510874
# Silhouette score for number of cluster(s) 6: 0.6143967708371331
# Davies Bouldin score for number of cluster(s) 6: 0.6628952793094931
# V-measure score for number of cluster(s) 6: 0.9589966883245079
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 7: -2.762148907762269
# Silhouette score for number of cluster(s) 7: 0.533352346539042
# Davies Bouldin score for number of cluster(s) 7: 0.8843548799013281
# V-measure score for number of cluster(s) 7: 0.9210253673885541
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 8: -2.5592148887749278
# Silhouette score for number of cluster(s) 8: 0.43845634950490847
# Davies Bouldin score for number of cluster(s) 8: 1.0893820470330982
# V-measure score for number of cluster(s) 8: 0.8889468662198046
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 9: -2.3851213585167117
# Silhouette score for number of cluster(s) 9: 0.3583923601112086
# Davies Bouldin score for number of cluster(s) 9: 1.1766411595376554
# V-measure score for number of cluster(s) 9: 0.8647679654439493
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 10: -2.241080975707088
# Silhouette score for number of cluster(s) 10: 0.2659448858646153
# Davies Bouldin score for number of cluster(s) 10: 1.3157035347717305
# V-measure score for number of cluster(s) 10: 0.8355215488134102
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 11: -2.1152301286259703
# Silhouette score for number of cluster(s) 11: 0.26536357672351185
# Davies Bouldin score for number of cluster(s) 11: 1.3476315420216567
# V-measure score for number of cluster(s) 11: 0.8136147413107119
# ----------------------------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
plt.figure(figsize=(7,4))
plt.title("The elbow method for determining number of clusters\n",fontsize=16)
plt.scatter(x=[i for i in range(2,12)],y=km_scores,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Number of clusters",fontsize=14)
plt.ylabel("K-means score",fontsize=15)
plt.xticks([i for i in range(2,12)],fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.scatter(x=[i for i in range(2,12)],y=vmeasure_score,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("V-measure score")
plt.show()

# %%
plt.figure(figsize=(7,4))
plt.title("The silhouette coefficient method \nfor determining number of clusters\n",fontsize=16)
plt.scatter(x=[i for i in range(2,12)],y=km_silhouette,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Number of clusters",fontsize=14)
plt.ylabel("Silhouette score",fontsize=15)
plt.xticks([i for i in range(2,12)],fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.scatter(x=[i for i in range(2,12)],y=db_score,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Davies-Bouldin score")
plt.show()

# %% [markdown]
# ## Expectation-maximization (Gaussian Mixture Model)

# %%
from sklearn.mixture import GaussianMixture

# %%
gm_bic= []
gm_score=[]
for i in range(2,12):
    gm = GaussianMixture(n_components=i,n_init=10,tol=1e-3,max_iter=1000).fit(X_scaled)
    print("BIC for number of cluster(s) {}: {}".format(i,gm.bic(X_scaled)))
    print("Log-likelihood score for number of cluster(s) {}: {}".format(i,gm.score(X_scaled)))
    print("-"*100)
    gm_bic.append(-gm.bic(X_scaled))
    gm_score.append(gm.score(X_scaled))
# Out:
# BIC for number of cluster(s) 2: -771.3890904732501
# Log-likelihood score for number of cluster(s) 2: 2.312600735257858
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 3: -1111.2859334331729
# Log-likelihood score for number of cluster(s) 3: 3.361029743903216
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 4: -1183.9936447548807
# Log-likelihood score for number of cluster(s) 4: 3.741485923453037
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 5: -1232.205180695861
# Log-likelihood score for number of cluster(s) 5: 4.060701664551039
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 6: -1198.6085752786573
# Log-likelihood score for number of cluster(s) 6: 4.175397052253581
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 7: -1136.2619318975044
# Log-likelihood score for number of cluster(s) 7: 4.21821734504625
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 8: -1092.913758453009
# Log-likelihood score for number of cluster(s) 8: 4.3085338126805635
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 9: -1047.6692817083444
# Log-likelihood score for number of cluster(s) 9: 4.394109522064453
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 10: -991.3571119163943
# Log-likelihood score for number of cluster(s) 10: 4.452015998830129
# ----------------------------------------------------------------------------------------------------
# BIC for number of cluster(s) 11: -938.8481944924886
# Log-likelihood score for number of cluster(s) 11: 4.519430606515916
# ----------------------------------------------------------------------------------------------------

# %%
plt.figure(figsize=(7,4))
plt.title("The Gaussian Mixture model BIC \nfor determining number of clusters\n",fontsize=16)
plt.scatter(x=[i for i in range(2,12)],y=np.log(gm_bic),s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Number of clusters",fontsize=14)
plt.ylabel("Log of Gaussian mixture BIC score",fontsize=15)
plt.xticks([i for i in range(2,12)],fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.scatter(x=[i for i in range(2,12)],y=gm_score,s=150,edgecolor='k')
plt.show()
