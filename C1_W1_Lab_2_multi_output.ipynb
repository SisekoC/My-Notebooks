# %% [markdown]
# <a href="https://colab.research.google.com/github/SisekoC/My-Notebooks/blob/main/C1_W1_Lab_2_multi_output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %%
## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train.columns),))
first_dense = Dense(units=128, activation='relu')(input_layer)
second_dense = Dense(units=128, activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units=1, name='y1_output')(second_dense)
third_dense = Dense(units=64, activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units=1, name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 8)              │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 128)            │          1,152 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 128)            │         16,512 │ dense_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 64)             │          8,256 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ y1_output (Dense)         │ (None, 1)              │            129 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ y2_output (Dense)         │ (None, 1)              │             65 │ dense_5[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 26,114 (102.01 KB)
#  Trainable params: 26,114 (102.01 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Epoch 1/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 522.8791 - y1_output_root_mean_squared_error: 15.4632 - y2_output_root_mean_squared_error: 15.6318 - val_loss: 24.6349 - val_y1_output_root_mean_squared_error: 3.5219 - val_y2_output_root_mean_squared_error: 3.4973
# Epoch 2/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.0713 - y1_output_root_mean_squared_error: 3.4733 - y2_output_root_mean_squared_error: 4.1015 - val_loss: 22.4656 - val_y1_output_root_mean_squared_error: 3.0831 - val_y2_output_root_mean_squared_error: 3.6000
# Epoch 3/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.3996 - y1_output_root_mean_squared_error: 3.4918 - y2_output_root_mean_squared_error: 4.4662 - val_loss: 22.9739 - val_y1_output_root_mean_squared_error: 3.2930 - val_y2_output_root_mean_squared_error: 3.4829
# Epoch 4/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.1342 - y1_output_root_mean_squared_error: 3.0030 - y2_output_root_mean_squared_error: 3.6132 - val_loss: 15.6791 - val_y1_output_root_mean_squared_error: 2.8171 - val_y2_output_root_mean_squared_error: 2.7826
# Epoch 5/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.9219 - y1_output_root_mean_squared_error: 3.0784 - y2_output_root_mean_squared_error: 3.7960 - val_loss: 49.0140 - val_y1_output_root_mean_squared_error: 3.7070 - val_y2_output_root_mean_squared_error: 5.9390
# Epoch 6/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 26.2233 - y1_output_root_mean_squared_error: 3.2229 - y2_output_root_mean_squared_error: 3.9509 - val_loss: 15.2041 - val_y1_output_root_mean_squared_error: 2.7678 - val_y2_output_root_mean_squared_error: 2.7465
# Epoch 7/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.4002 - y1_output_root_mean_squared_error: 2.9949 - y2_output_root_mean_squared_error: 3.5126 - val_loss: 16.7717 - val_y1_output_root_mean_squared_error: 2.7013 - val_y2_output_root_mean_squared_error: 3.0781
# Epoch 8/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.6521 - y1_output_root_mean_squared_error: 2.9350 - y2_output_root_mean_squared_error: 3.7260 - val_loss: 20.6227 - val_y1_output_root_mean_squared_error: 3.1832 - val_y2_output_root_mean_squared_error: 3.2388
# Epoch 9/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.4727 - y1_output_root_mean_squared_error: 2.8847 - y2_output_root_mean_squared_error: 3.7518 - val_loss: 88.4070 - val_y1_output_root_mean_squared_error: 5.0480 - val_y2_output_root_mean_squared_error: 7.9325
# Epoch 10/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30.1454 - y1_output_root_mean_squared_error: 3.1942 - y2_output_root_mean_squared_error: 4.4259 - val_loss: 14.7784 - val_y1_output_root_mean_squared_error: 2.7547 - val_y2_output_root_mean_squared_error: 2.6814
# Epoch 11/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 20.1053 - y1_output_root_mean_squared_error: 2.8118 - y2_output_root_mean_squared_error: 3.4770 - val_loss: 12.7752 - val_y1_output_root_mean_squared_error: 2.5323 - val_y2_output_root_mean_squared_error: 2.5225
# Epoch 12/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.3454 - y1_output_root_mean_squared_error: 2.7236 - y2_output_root_mean_squared_error: 3.4402 - val_loss: 12.4593 - val_y1_output_root_mean_squared_error: 2.4544 - val_y2_output_root_mean_squared_error: 2.5368
# Epoch 13/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 23.1705 - y1_output_root_mean_squared_error: 2.8314 - y2_output_root_mean_squared_error: 3.8801 - val_loss: 30.9472 - val_y1_output_root_mean_squared_error: 3.1336 - val_y2_output_root_mean_squared_error: 4.5965
# Epoch 14/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 17.5460 - y1_output_root_mean_squared_error: 2.5311 - y2_output_root_mean_squared_error: 3.3278 - val_loss: 12.4116 - val_y1_output_root_mean_squared_error: 2.3823 - val_y2_output_root_mean_squared_error: 2.5955
# Epoch 15/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 17.0180 - y1_output_root_mean_squared_error: 2.6284 - y2_output_root_mean_squared_error: 3.1664 - val_loss: 17.3678 - val_y1_output_root_mean_squared_error: 2.4745 - val_y2_output_root_mean_squared_error: 3.3533
# Epoch 16/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.2425 - y1_output_root_mean_squared_error: 2.7881 - y2_output_root_mean_squared_error: 3.7753 - val_loss: 13.8111 - val_y1_output_root_mean_squared_error: 2.4188 - val_y2_output_root_mean_squared_error: 2.8215
# Epoch 17/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.7404 - y1_output_root_mean_squared_error: 2.5857 - y2_output_root_mean_squared_error: 2.9997 - val_loss: 11.3036 - val_y1_output_root_mean_squared_error: 2.2497 - val_y2_output_root_mean_squared_error: 2.4985
# Epoch 18/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.7838 - y1_output_root_mean_squared_error: 2.3105 - y2_output_root_mean_squared_error: 2.8745 - val_loss: 15.0147 - val_y1_output_root_mean_squared_error: 2.3214 - val_y2_output_root_mean_squared_error: 3.1025
# Epoch 19/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.2817 - y1_output_root_mean_squared_error: 2.2404 - y2_output_root_mean_squared_error: 2.8668 - val_loss: 11.6407 - val_y1_output_root_mean_squared_error: 2.3458 - val_y2_output_root_mean_squared_error: 2.4775
# Epoch 20/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.3289 - y1_output_root_mean_squared_error: 2.3644 - y2_output_root_mean_squared_error: 3.2490 - val_loss: 22.7721 - val_y1_output_root_mean_squared_error: 2.7109 - val_y2_output_root_mean_squared_error: 3.9272
# Epoch 21/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.0775 - y1_output_root_mean_squared_error: 2.4353 - y2_output_root_mean_squared_error: 3.0148 - val_loss: 10.4508 - val_y1_output_root_mean_squared_error: 2.1216 - val_y2_output_root_mean_squared_error: 2.4391
# Epoch 22/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.6790 - y1_output_root_mean_squared_error: 2.1141 - y2_output_root_mean_squared_error: 2.6578 - val_loss: 11.1798 - val_y1_output_root_mean_squared_error: 2.2282 - val_y2_output_root_mean_squared_error: 2.4930
# Epoch 23/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.0206 - y1_output_root_mean_squared_error: 2.1620 - y2_output_root_mean_squared_error: 2.8659 - val_loss: 10.5271 - val_y1_output_root_mean_squared_error: 2.1310 - val_y2_output_root_mean_squared_error: 2.4466
# Epoch 24/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.6877 - y1_output_root_mean_squared_error: 1.9694 - y2_output_root_mean_squared_error: 2.5984 - val_loss: 14.1209 - val_y1_output_root_mean_squared_error: 2.0570 - val_y2_output_root_mean_squared_error: 3.1448
# Epoch 25/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.4416 - y1_output_root_mean_squared_error: 2.0820 - y2_output_root_mean_squared_error: 2.6597 - val_loss: 22.7849 - val_y1_output_root_mean_squared_error: 2.2052 - val_y2_output_root_mean_squared_error: 4.2334
# Epoch 26/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 17.4746 - y1_output_root_mean_squared_error: 2.3828 - y2_output_root_mean_squared_error: 3.4173 - val_loss: 21.1275 - val_y1_output_root_mean_squared_error: 2.2329 - val_y2_output_root_mean_squared_error: 4.0177
# Epoch 27/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.6494 - y1_output_root_mean_squared_error: 1.9111 - y2_output_root_mean_squared_error: 2.7963 - val_loss: 10.7691 - val_y1_output_root_mean_squared_error: 1.9214 - val_y2_output_root_mean_squared_error: 2.6603
# Epoch 28/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.1302 - y1_output_root_mean_squared_error: 1.8513 - y2_output_root_mean_squared_error: 2.5837 - val_loss: 9.2349 - val_y1_output_root_mean_squared_error: 2.0614 - val_y2_output_root_mean_squared_error: 2.2328
# Epoch 29/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.4546 - y1_output_root_mean_squared_error: 2.1841 - y2_output_root_mean_squared_error: 2.9239 - val_loss: 10.6196 - val_y1_output_root_mean_squared_error: 1.9278 - val_y2_output_root_mean_squared_error: 2.6274
# Epoch 30/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7709 - y1_output_root_mean_squared_error: 1.8501 - y2_output_root_mean_squared_error: 2.4968 - val_loss: 15.0033 - val_y1_output_root_mean_squared_error: 2.3142 - val_y2_output_root_mean_squared_error: 3.1061
# Epoch 31/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.7503 - y1_output_root_mean_squared_error: 1.9975 - y2_output_root_mean_squared_error: 2.5834 - val_loss: 9.5830 - val_y1_output_root_mean_squared_error: 1.7589 - val_y2_output_root_mean_squared_error: 2.5474
# Epoch 32/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7305 - y1_output_root_mean_squared_error: 1.8052 - y2_output_root_mean_squared_error: 2.3309 - val_loss: 13.5075 - val_y1_output_root_mean_squared_error: 1.9070 - val_y2_output_root_mean_squared_error: 3.1418
# Epoch 33/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.2596 - y1_output_root_mean_squared_error: 2.1371 - y2_output_root_mean_squared_error: 2.9277 - val_loss: 18.9097 - val_y1_output_root_mean_squared_error: 1.9405 - val_y2_output_root_mean_squared_error: 3.8915
# Epoch 34/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.4684 - y1_output_root_mean_squared_error: 1.8919 - y2_output_root_mean_squared_error: 2.6171 - val_loss: 22.4184 - val_y1_output_root_mean_squared_error: 2.5769 - val_y2_output_root_mean_squared_error: 3.9721
# Epoch 35/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.3511 - y1_output_root_mean_squared_error: 1.8898 - y2_output_root_mean_squared_error: 2.3803 - val_loss: 8.7806 - val_y1_output_root_mean_squared_error: 1.6788 - val_y2_output_root_mean_squared_error: 2.4418
# Epoch 36/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6432 - y1_output_root_mean_squared_error: 1.7491 - y2_output_root_mean_squared_error: 2.3441 - val_loss: 7.8191 - val_y1_output_root_mean_squared_error: 1.6549 - val_y2_output_root_mean_squared_error: 2.2540
# Epoch 37/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9660 - y1_output_root_mean_squared_error: 1.8917 - y2_output_root_mean_squared_error: 2.5109 - val_loss: 10.2285 - val_y1_output_root_mean_squared_error: 1.7334 - val_y2_output_root_mean_squared_error: 2.6877
# Epoch 38/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4034 - y1_output_root_mean_squared_error: 1.6052 - y2_output_root_mean_squared_error: 2.1830 - val_loss: 7.7419 - val_y1_output_root_mean_squared_error: 1.5629 - val_y2_output_root_mean_squared_error: 2.3020
# Epoch 39/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7976 - y1_output_root_mean_squared_error: 1.4916 - y2_output_root_mean_squared_error: 2.1359 - val_loss: 10.9716 - val_y1_output_root_mean_squared_error: 1.8440 - val_y2_output_root_mean_squared_error: 2.7516
# Epoch 40/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.9073 - y1_output_root_mean_squared_error: 1.6824 - y2_output_root_mean_squared_error: 2.2482 - val_loss: 9.1732 - val_y1_output_root_mean_squared_error: 1.7622 - val_y2_output_root_mean_squared_error: 2.4633
# Epoch 41/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4558 - y1_output_root_mean_squared_error: 1.6716 - y2_output_root_mean_squared_error: 2.3754 - val_loss: 8.8350 - val_y1_output_root_mean_squared_error: 1.7170 - val_y2_output_root_mean_squared_error: 2.4263
# Epoch 42/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.2045 - y1_output_root_mean_squared_error: 1.5129 - y2_output_root_mean_squared_error: 2.2052 - val_loss: 8.8715 - val_y1_output_root_mean_squared_error: 1.7452 - val_y2_output_root_mean_squared_error: 2.4137
# Epoch 43/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.3819 - y1_output_root_mean_squared_error: 1.6184 - y2_output_root_mean_squared_error: 2.5861 - val_loss: 7.7084 - val_y1_output_root_mean_squared_error: 1.6091 - val_y2_output_root_mean_squared_error: 2.2626
# Epoch 44/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4407 - y1_output_root_mean_squared_error: 1.5192 - y2_output_root_mean_squared_error: 2.0241 - val_loss: 7.9866 - val_y1_output_root_mean_squared_error: 1.6083 - val_y2_output_root_mean_squared_error: 2.3238
# Epoch 45/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7217 - y1_output_root_mean_squared_error: 1.4571 - y2_output_root_mean_squared_error: 2.3602 - val_loss: 23.4198 - val_y1_output_root_mean_squared_error: 2.8271 - val_y2_output_root_mean_squared_error: 3.9278
# Epoch 46/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5045 - y1_output_root_mean_squared_error: 1.6793 - y2_output_root_mean_squared_error: 2.3515 - val_loss: 9.2057 - val_y1_output_root_mean_squared_error: 1.8123 - val_y2_output_root_mean_squared_error: 2.4333
# Epoch 47/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1126 - y1_output_root_mean_squared_error: 1.4297 - y2_output_root_mean_squared_error: 2.0082 - val_loss: 8.4068 - val_y1_output_root_mean_squared_error: 1.4824 - val_y2_output_root_mean_squared_error: 2.4918
# Epoch 48/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4277 - y1_output_root_mean_squared_error: 1.5101 - y2_output_root_mean_squared_error: 2.0274 - val_loss: 16.9824 - val_y1_output_root_mean_squared_error: 1.8633 - val_y2_output_root_mean_squared_error: 3.6757
# Epoch 49/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1042 - y1_output_root_mean_squared_error: 1.6304 - y2_output_root_mean_squared_error: 2.0969 - val_loss: 11.6209 - val_y1_output_root_mean_squared_error: 1.4041 - val_y2_output_root_mean_squared_error: 3.1064
# Epoch 50/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.8975 - y1_output_root_mean_squared_error: 1.8369 - y2_output_root_mean_squared_error: 2.8901 - val_loss: 6.1821 - val_y1_output_root_mean_squared_error: 1.4610 - val_y2_output_root_mean_squared_error: 2.0119
# Epoch 51/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5617 - y1_output_root_mean_squared_error: 1.4869 - y2_output_root_mean_squared_error: 2.0706 - val_loss: 10.3469 - val_y1_output_root_mean_squared_error: 1.5683 - val_y2_output_root_mean_squared_error: 2.8084
# Epoch 52/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1980 - y1_output_root_mean_squared_error: 1.4563 - y2_output_root_mean_squared_error: 2.2402 - val_loss: 9.9753 - val_y1_output_root_mean_squared_error: 1.5914 - val_y2_output_root_mean_squared_error: 2.7282
# Epoch 53/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1018 - y1_output_root_mean_squared_error: 1.3904 - y2_output_root_mean_squared_error: 2.0401 - val_loss: 10.5257 - val_y1_output_root_mean_squared_error: 1.9372 - val_y2_output_root_mean_squared_error: 2.6025
# Epoch 54/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.4304 - y1_output_root_mean_squared_error: 1.7413 - y2_output_root_mean_squared_error: 2.4714 - val_loss: 10.6187 - val_y1_output_root_mean_squared_error: 1.6029 - val_y2_output_root_mean_squared_error: 2.8372
# Epoch 55/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1057 - y1_output_root_mean_squared_error: 1.3582 - y2_output_root_mean_squared_error: 2.0587 - val_loss: 18.3435 - val_y1_output_root_mean_squared_error: 2.4062 - val_y2_output_root_mean_squared_error: 3.5431
# Epoch 56/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9362 - y1_output_root_mean_squared_error: 1.5950 - y2_output_root_mean_squared_error: 2.2996 - val_loss: 5.5783 - val_y1_output_root_mean_squared_error: 1.3819 - val_y2_output_root_mean_squared_error: 1.9154
# Epoch 57/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8955 - y1_output_root_mean_squared_error: 1.2056 - y2_output_root_mean_squared_error: 1.8499 - val_loss: 13.3347 - val_y1_output_root_mean_squared_error: 2.1679 - val_y2_output_root_mean_squared_error: 2.9385
# Epoch 58/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4690 - y1_output_root_mean_squared_error: 1.4813 - y2_output_root_mean_squared_error: 2.0580 - val_loss: 6.7246 - val_y1_output_root_mean_squared_error: 1.4281 - val_y2_output_root_mean_squared_error: 2.1645
# Epoch 59/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1220 - y1_output_root_mean_squared_error: 1.4344 - y2_output_root_mean_squared_error: 1.9960 - val_loss: 6.1563 - val_y1_output_root_mean_squared_error: 1.3497 - val_y2_output_root_mean_squared_error: 2.0820
# Epoch 60/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9364 - y1_output_root_mean_squared_error: 1.2327 - y2_output_root_mean_squared_error: 1.8426 - val_loss: 5.3800 - val_y1_output_root_mean_squared_error: 1.2592 - val_y2_output_root_mean_squared_error: 1.9479
# Epoch 61/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4399 - y1_output_root_mean_squared_error: 1.3188 - y2_output_root_mean_squared_error: 1.9096 - val_loss: 90.9123 - val_y1_output_root_mean_squared_error: 5.1192 - val_y2_output_root_mean_squared_error: 8.0440
# Epoch 62/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.5873 - y1_output_root_mean_squared_error: 2.7581 - y2_output_root_mean_squared_error: 4.2735 - val_loss: 5.2076 - val_y1_output_root_mean_squared_error: 1.2216 - val_y2_output_root_mean_squared_error: 1.9275
# Epoch 63/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6142 - y1_output_root_mean_squared_error: 1.3636 - y2_output_root_mean_squared_error: 2.1757 - val_loss: 10.3419 - val_y1_output_root_mean_squared_error: 1.5404 - val_y2_output_root_mean_squared_error: 2.8230
# Epoch 64/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8003 - y1_output_root_mean_squared_error: 1.2636 - y2_output_root_mean_squared_error: 1.7873 - val_loss: 5.0012 - val_y1_output_root_mean_squared_error: 1.2359 - val_y2_output_root_mean_squared_error: 1.8638
# Epoch 65/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1129 - y1_output_root_mean_squared_error: 1.2826 - y2_output_root_mean_squared_error: 2.1058 - val_loss: 7.9616 - val_y1_output_root_mean_squared_error: 1.4012 - val_y2_output_root_mean_squared_error: 2.4491
# Epoch 66/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3090 - y1_output_root_mean_squared_error: 1.1313 - y2_output_root_mean_squared_error: 1.9962 - val_loss: 10.8397 - val_y1_output_root_mean_squared_error: 1.4795 - val_y2_output_root_mean_squared_error: 2.9412
# Epoch 67/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.0967 - y1_output_root_mean_squared_error: 1.5932 - y2_output_root_mean_squared_error: 2.4683 - val_loss: 4.6708 - val_y1_output_root_mean_squared_error: 1.1203 - val_y2_output_root_mean_squared_error: 1.8482
# Epoch 68/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3420 - y1_output_root_mean_squared_error: 1.0290 - y2_output_root_mean_squared_error: 1.8020 - val_loss: 4.4429 - val_y1_output_root_mean_squared_error: 1.1337 - val_y2_output_root_mean_squared_error: 1.7770
# Epoch 69/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1621 - y1_output_root_mean_squared_error: 1.1991 - y2_output_root_mean_squared_error: 1.8957 - val_loss: 7.2020 - val_y1_output_root_mean_squared_error: 1.1358 - val_y2_output_root_mean_squared_error: 2.4314
# Epoch 70/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9077 - y1_output_root_mean_squared_error: 1.1762 - y2_output_root_mean_squared_error: 2.0823 - val_loss: 4.1982 - val_y1_output_root_mean_squared_error: 0.9997 - val_y2_output_root_mean_squared_error: 1.7885
# Epoch 71/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3218 - y1_output_root_mean_squared_error: 1.1412 - y2_output_root_mean_squared_error: 1.7240 - val_loss: 4.1742 - val_y1_output_root_mean_squared_error: 1.0632 - val_y2_output_root_mean_squared_error: 1.7447
# Epoch 72/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6480 - y1_output_root_mean_squared_error: 1.2852 - y2_output_root_mean_squared_error: 1.9801 - val_loss: 4.0624 - val_y1_output_root_mean_squared_error: 1.1007 - val_y2_output_root_mean_squared_error: 1.6884
# Epoch 73/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5539 - y1_output_root_mean_squared_error: 1.1059 - y2_output_root_mean_squared_error: 1.8171 - val_loss: 3.8337 - val_y1_output_root_mean_squared_error: 1.0575 - val_y2_output_root_mean_squared_error: 1.6479
# Epoch 74/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6897 - y1_output_root_mean_squared_error: 0.9955 - y2_output_root_mean_squared_error: 1.6330 - val_loss: 4.2471 - val_y1_output_root_mean_squared_error: 1.1885 - val_y2_output_root_mean_squared_error: 1.6836
# Epoch 75/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9008 - y1_output_root_mean_squared_error: 0.9141 - y2_output_root_mean_squared_error: 1.4331 - val_loss: 7.1069 - val_y1_output_root_mean_squared_error: 1.4044 - val_y2_output_root_mean_squared_error: 2.2659
# Epoch 76/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4758 - y1_output_root_mean_squared_error: 1.1755 - y2_output_root_mean_squared_error: 2.0057 - val_loss: 18.2905 - val_y1_output_root_mean_squared_error: 2.7147 - val_y2_output_root_mean_squared_error: 3.3047
# Epoch 77/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.8005 - y1_output_root_mean_squared_error: 1.7882 - y2_output_root_mean_squared_error: 2.6165 - val_loss: 5.3467 - val_y1_output_root_mean_squared_error: 1.2874 - val_y2_output_root_mean_squared_error: 1.9208
# Epoch 78/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8669 - y1_output_root_mean_squared_error: 1.2046 - y2_output_root_mean_squared_error: 1.8191 - val_loss: 5.1668 - val_y1_output_root_mean_squared_error: 1.0155 - val_y2_output_root_mean_squared_error: 2.0336
# Epoch 79/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9842 - y1_output_root_mean_squared_error: 0.8862 - y2_output_root_mean_squared_error: 1.4765 - val_loss: 3.8732 - val_y1_output_root_mean_squared_error: 0.9741 - val_y2_output_root_mean_squared_error: 1.7101
# Epoch 80/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.0415 - y1_output_root_mean_squared_error: 0.9112 - y2_output_root_mean_squared_error: 1.4842 - val_loss: 7.7814 - val_y1_output_root_mean_squared_error: 1.2520 - val_y2_output_root_mean_squared_error: 2.4928
# Epoch 81/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1031 - y1_output_root_mean_squared_error: 1.2140 - y2_output_root_mean_squared_error: 1.8761 - val_loss: 3.3957 - val_y1_output_root_mean_squared_error: 0.9201 - val_y2_output_root_mean_squared_error: 1.5966
# Epoch 82/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.0393 - y1_output_root_mean_squared_error: 0.9151 - y2_output_root_mean_squared_error: 1.4742 - val_loss: 2.8783 - val_y1_output_root_mean_squared_error: 0.7766 - val_y2_output_root_mean_squared_error: 1.5084
# Epoch 83/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 3.1815 - y1_output_root_mean_squared_error: 0.9006 - y2_output_root_mean_squared_error: 1.5332 - val_loss: 3.4057 - val_y1_output_root_mean_squared_error: 0.7900 - val_y2_output_root_mean_squared_error: 1.6678
# Epoch 84/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.2216 - y1_output_root_mean_squared_error: 0.8195 - y2_output_root_mean_squared_error: 1.5907 - val_loss: 4.5993 - val_y1_output_root_mean_squared_error: 0.8027 - val_y2_output_root_mean_squared_error: 1.9887
# Epoch 85/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2670 - y1_output_root_mean_squared_error: 0.8323 - y2_output_root_mean_squared_error: 1.6004 - val_loss: 3.2303 - val_y1_output_root_mean_squared_error: 0.8872 - val_y2_output_root_mean_squared_error: 1.5631
# Epoch 86/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3022 - y1_output_root_mean_squared_error: 0.8756 - y2_output_root_mean_squared_error: 1.5864 - val_loss: 4.3484 - val_y1_output_root_mean_squared_error: 1.1527 - val_y2_output_root_mean_squared_error: 1.7377
# Epoch 87/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1783 - y1_output_root_mean_squared_error: 0.9335 - y2_output_root_mean_squared_error: 1.5114 - val_loss: 10.6151 - val_y1_output_root_mean_squared_error: 1.2210 - val_y2_output_root_mean_squared_error: 3.0206
# Epoch 88/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4317 - y1_output_root_mean_squared_error: 0.9615 - y2_output_root_mean_squared_error: 1.5745 - val_loss: 3.9142 - val_y1_output_root_mean_squared_error: 1.0388 - val_y2_output_root_mean_squared_error: 1.6837
# Epoch 89/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5432 - y1_output_root_mean_squared_error: 0.9880 - y2_output_root_mean_squared_error: 1.8762 - val_loss: 3.8619 - val_y1_output_root_mean_squared_error: 0.8812 - val_y2_output_root_mean_squared_error: 1.7565
# Epoch 90/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5822 - y1_output_root_mean_squared_error: 0.8154 - y2_output_root_mean_squared_error: 1.3808 - val_loss: 7.3374 - val_y1_output_root_mean_squared_error: 0.9777 - val_y2_output_root_mean_squared_error: 2.5261
# Epoch 91/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2842 - y1_output_root_mean_squared_error: 0.8365 - y2_output_root_mean_squared_error: 1.5915 - val_loss: 3.7043 - val_y1_output_root_mean_squared_error: 0.7409 - val_y2_output_root_mean_squared_error: 1.7763
# Epoch 92/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7689 - y1_output_root_mean_squared_error: 1.0944 - y2_output_root_mean_squared_error: 1.8021 - val_loss: 2.6947 - val_y1_output_root_mean_squared_error: 0.7847 - val_y2_output_root_mean_squared_error: 1.4418
# Epoch 93/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4616 - y1_output_root_mean_squared_error: 0.7715 - y2_output_root_mean_squared_error: 1.3643 - val_loss: 3.0497 - val_y1_output_root_mean_squared_error: 0.7728 - val_y2_output_root_mean_squared_error: 1.5660
# Epoch 94/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4450 - y1_output_root_mean_squared_error: 0.8904 - y2_output_root_mean_squared_error: 1.6049 - val_loss: 3.2904 - val_y1_output_root_mean_squared_error: 0.7400 - val_y2_output_root_mean_squared_error: 1.6562
# Epoch 95/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8420 - y1_output_root_mean_squared_error: 0.8690 - y2_output_root_mean_squared_error: 1.4398 - val_loss: 2.8030 - val_y1_output_root_mean_squared_error: 0.7571 - val_y2_output_root_mean_squared_error: 1.4932
# Epoch 96/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9214 - y1_output_root_mean_squared_error: 0.8082 - y2_output_root_mean_squared_error: 1.5013 - val_loss: 4.5710 - val_y1_output_root_mean_squared_error: 1.1806 - val_y2_output_root_mean_squared_error: 1.7825
# Epoch 97/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3400 - y1_output_root_mean_squared_error: 0.8166 - y2_output_root_mean_squared_error: 1.2809 - val_loss: 4.1234 - val_y1_output_root_mean_squared_error: 0.9484 - val_y2_output_root_mean_squared_error: 1.7955
# Epoch 98/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0504 - y1_output_root_mean_squared_error: 1.3595 - y2_output_root_mean_squared_error: 2.0336 - val_loss: 2.9162 - val_y1_output_root_mean_squared_error: 0.7908 - val_y2_output_root_mean_squared_error: 1.5136
# Epoch 99/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3803 - y1_output_root_mean_squared_error: 0.7855 - y2_output_root_mean_squared_error: 1.3249 - val_loss: 3.3336 - val_y1_output_root_mean_squared_error: 0.7423 - val_y2_output_root_mean_squared_error: 1.6681
# Epoch 100/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6134 - y1_output_root_mean_squared_error: 1.0977 - y2_output_root_mean_squared_error: 1.8186 - val_loss: 6.3675 - val_y1_output_root_mean_squared_error: 1.1853 - val_y2_output_root_mean_squared_error: 2.2277
# Epoch 101/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9287 - y1_output_root_mean_squared_error: 0.8589 - y2_output_root_mean_squared_error: 1.4715 - val_loss: 5.5680 - val_y1_output_root_mean_squared_error: 0.8231 - val_y2_output_root_mean_squared_error: 2.2114
# Epoch 102/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6779 - y1_output_root_mean_squared_error: 0.7927 - y2_output_root_mean_squared_error: 1.4164 - val_loss: 3.3177 - val_y1_output_root_mean_squared_error: 0.9591 - val_y2_output_root_mean_squared_error: 1.5485
# Epoch 103/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8746 - y1_output_root_mean_squared_error: 0.8432 - y2_output_root_mean_squared_error: 1.4612 - val_loss: 5.0063 - val_y1_output_root_mean_squared_error: 1.0202 - val_y2_output_root_mean_squared_error: 1.9914
# Epoch 104/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4892 - y1_output_root_mean_squared_error: 0.8438 - y2_output_root_mean_squared_error: 1.3275 - val_loss: 3.4900 - val_y1_output_root_mean_squared_error: 0.9635 - val_y2_output_root_mean_squared_error: 1.6005
# Epoch 105/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8694 - y1_output_root_mean_squared_error: 0.8373 - y2_output_root_mean_squared_error: 1.4551 - val_loss: 3.1863 - val_y1_output_root_mean_squared_error: 0.7768 - val_y2_output_root_mean_squared_error: 1.6072
# Epoch 106/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7355 - y1_output_root_mean_squared_error: 0.8750 - y2_output_root_mean_squared_error: 1.3997 - val_loss: 2.9173 - val_y1_output_root_mean_squared_error: 0.6710 - val_y2_output_root_mean_squared_error: 1.5707
# Epoch 107/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3926 - y1_output_root_mean_squared_error: 0.7546 - y2_output_root_mean_squared_error: 1.3437 - val_loss: 2.4689 - val_y1_output_root_mean_squared_error: 0.6585 - val_y2_output_root_mean_squared_error: 1.4266
# Epoch 108/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0304 - y1_output_root_mean_squared_error: 0.6312 - y2_output_root_mean_squared_error: 1.2741 - val_loss: 5.7927 - val_y1_output_root_mean_squared_error: 0.7455 - val_y2_output_root_mean_squared_error: 2.2884
# Epoch 109/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8873 - y1_output_root_mean_squared_error: 0.8833 - y2_output_root_mean_squared_error: 1.4381 - val_loss: 4.9653 - val_y1_output_root_mean_squared_error: 0.7967 - val_y2_output_root_mean_squared_error: 2.0810
# Epoch 110/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2018 - y1_output_root_mean_squared_error: 0.6766 - y2_output_root_mean_squared_error: 1.3180 - val_loss: 2.8130 - val_y1_output_root_mean_squared_error: 0.7436 - val_y2_output_root_mean_squared_error: 1.5034
# Epoch 111/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1185 - y1_output_root_mean_squared_error: 0.7333 - y2_output_root_mean_squared_error: 1.2418 - val_loss: 2.5475 - val_y1_output_root_mean_squared_error: 0.7681 - val_y2_output_root_mean_squared_error: 1.3991
# Epoch 112/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0395 - y1_output_root_mean_squared_error: 0.6930 - y2_output_root_mean_squared_error: 1.2469 - val_loss: 9.8644 - val_y1_output_root_mean_squared_error: 1.2161 - val_y2_output_root_mean_squared_error: 2.8958
# Epoch 113/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8687 - y1_output_root_mean_squared_error: 0.8772 - y2_output_root_mean_squared_error: 1.7498 - val_loss: 2.8285 - val_y1_output_root_mean_squared_error: 0.8395 - val_y2_output_root_mean_squared_error: 1.4573
# Epoch 114/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4634 - y1_output_root_mean_squared_error: 0.8115 - y2_output_root_mean_squared_error: 1.3393 - val_loss: 2.6168 - val_y1_output_root_mean_squared_error: 0.6587 - val_y2_output_root_mean_squared_error: 1.4775
# Epoch 115/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1296 - y1_output_root_mean_squared_error: 0.8670 - y2_output_root_mean_squared_error: 1.5340 - val_loss: 3.6046 - val_y1_output_root_mean_squared_error: 0.6696 - val_y2_output_root_mean_squared_error: 1.7766
# Epoch 116/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1655 - y1_output_root_mean_squared_error: 0.6974 - y2_output_root_mean_squared_error: 1.2882 - val_loss: 2.5291 - val_y1_output_root_mean_squared_error: 0.7315 - val_y2_output_root_mean_squared_error: 1.4121
# Epoch 117/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4182 - y1_output_root_mean_squared_error: 0.8531 - y2_output_root_mean_squared_error: 1.6235 - val_loss: 2.4472 - val_y1_output_root_mean_squared_error: 0.6805 - val_y2_output_root_mean_squared_error: 1.4086
# Epoch 118/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1517 - y1_output_root_mean_squared_error: 0.7567 - y2_output_root_mean_squared_error: 1.2539 - val_loss: 41.3277 - val_y1_output_root_mean_squared_error: 3.3606 - val_y2_output_root_mean_squared_error: 5.4804
# Epoch 119/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.9034 - y1_output_root_mean_squared_error: 2.5019 - y2_output_root_mean_squared_error: 3.4806 - val_loss: 7.2420 - val_y1_output_root_mean_squared_error: 0.9634 - val_y2_output_root_mean_squared_error: 2.5127
# Epoch 120/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4856 - y1_output_root_mean_squared_error: 0.8005 - y2_output_root_mean_squared_error: 1.3453 - val_loss: 2.3457 - val_y1_output_root_mean_squared_error: 0.6864 - val_y2_output_root_mean_squared_error: 1.3692
# Epoch 121/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9895 - y1_output_root_mean_squared_error: 0.6987 - y2_output_root_mean_squared_error: 1.2146 - val_loss: 15.2847 - val_y1_output_root_mean_squared_error: 2.0394 - val_y2_output_root_mean_squared_error: 3.3355
# Epoch 122/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4216 - y1_output_root_mean_squared_error: 0.8259 - y2_output_root_mean_squared_error: 1.3045 - val_loss: 2.2266 - val_y1_output_root_mean_squared_error: 0.6530 - val_y2_output_root_mean_squared_error: 1.3417
# Epoch 123/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5818 - y1_output_root_mean_squared_error: 0.6054 - y2_output_root_mean_squared_error: 1.1013 - val_loss: 2.0948 - val_y1_output_root_mean_squared_error: 0.6468 - val_y2_output_root_mean_squared_error: 1.2948
# Epoch 124/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.9976 - y1_output_root_mean_squared_error: 0.6818 - y2_output_root_mean_squared_error: 1.2263 - val_loss: 2.2063 - val_y1_output_root_mean_squared_error: 0.6876 - val_y2_output_root_mean_squared_error: 1.3166
# Epoch 125/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.6284 - y1_output_root_mean_squared_error: 0.5726 - y2_output_root_mean_squared_error: 1.1367 - val_loss: 24.9800 - val_y1_output_root_mean_squared_error: 2.6750 - val_y2_output_root_mean_squared_error: 4.2219
# Epoch 126/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.6511 - y1_output_root_mean_squared_error: 1.2381 - y2_output_root_mean_squared_error: 1.9573 - val_loss: 2.2082 - val_y1_output_root_mean_squared_error: 0.7315 - val_y2_output_root_mean_squared_error: 1.2935
# Epoch 127/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.8527 - y1_output_root_mean_squared_error: 0.6568 - y2_output_root_mean_squared_error: 1.1885 - val_loss: 3.3601 - val_y1_output_root_mean_squared_error: 0.7397 - val_y2_output_root_mean_squared_error: 1.6772
# Epoch 128/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2326 - y1_output_root_mean_squared_error: 0.7110 - y2_output_root_mean_squared_error: 1.3048 - val_loss: 4.1600 - val_y1_output_root_mean_squared_error: 0.8531 - val_y2_output_root_mean_squared_error: 1.8526
# Epoch 129/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4356 - y1_output_root_mean_squared_error: 0.6696 - y2_output_root_mean_squared_error: 1.3869 - val_loss: 3.8899 - val_y1_output_root_mean_squared_error: 0.6773 - val_y2_output_root_mean_squared_error: 1.8523
# Epoch 130/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4505 - y1_output_root_mean_squared_error: 0.7093 - y2_output_root_mean_squared_error: 1.3927 - val_loss: 6.9857 - val_y1_output_root_mean_squared_error: 0.8157 - val_y2_output_root_mean_squared_error: 2.5140
# Epoch 131/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6500 - y1_output_root_mean_squared_error: 0.6344 - y2_output_root_mean_squared_error: 1.1148 - val_loss: 2.8735 - val_y1_output_root_mean_squared_error: 0.8646 - val_y2_output_root_mean_squared_error: 1.4580
# Epoch 132/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7774 - y1_output_root_mean_squared_error: 0.6627 - y2_output_root_mean_squared_error: 1.1480 - val_loss: 2.2119 - val_y1_output_root_mean_squared_error: 0.6674 - val_y2_output_root_mean_squared_error: 1.3291
# Epoch 133/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6792 - y1_output_root_mean_squared_error: 0.6783 - y2_output_root_mean_squared_error: 1.0912 - val_loss: 2.2307 - val_y1_output_root_mean_squared_error: 0.5821 - val_y2_output_root_mean_squared_error: 1.3754
# Epoch 134/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3760 - y1_output_root_mean_squared_error: 0.6061 - y2_output_root_mean_squared_error: 0.9970 - val_loss: 11.1744 - val_y1_output_root_mean_squared_error: 1.7584 - val_y2_output_root_mean_squared_error: 2.8430
# Epoch 135/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0791 - y1_output_root_mean_squared_error: 1.0602 - y2_output_root_mean_squared_error: 1.6914 - val_loss: 2.3041 - val_y1_output_root_mean_squared_error: 0.6486 - val_y2_output_root_mean_squared_error: 1.3724
# Epoch 136/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9015 - y1_output_root_mean_squared_error: 0.6544 - y2_output_root_mean_squared_error: 1.2086 - val_loss: 2.7559 - val_y1_output_root_mean_squared_error: 0.7963 - val_y2_output_root_mean_squared_error: 1.4566
# Epoch 137/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6239 - y1_output_root_mean_squared_error: 0.6489 - y2_output_root_mean_squared_error: 1.0890 - val_loss: 2.9281 - val_y1_output_root_mean_squared_error: 0.7784 - val_y2_output_root_mean_squared_error: 1.5239
# Epoch 138/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1784 - y1_output_root_mean_squared_error: 0.7536 - y2_output_root_mean_squared_error: 1.2611 - val_loss: 2.5682 - val_y1_output_root_mean_squared_error: 0.5940 - val_y2_output_root_mean_squared_error: 1.4884
# Epoch 139/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5145 - y1_output_root_mean_squared_error: 0.5963 - y2_output_root_mean_squared_error: 1.0620 - val_loss: 2.3967 - val_y1_output_root_mean_squared_error: 0.5836 - val_y2_output_root_mean_squared_error: 1.4339
# Epoch 140/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4885 - y1_output_root_mean_squared_error: 0.5725 - y2_output_root_mean_squared_error: 1.0671 - val_loss: 2.0758 - val_y1_output_root_mean_squared_error: 0.5440 - val_y2_output_root_mean_squared_error: 1.3341
# Epoch 141/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6902 - y1_output_root_mean_squared_error: 0.5640 - y2_output_root_mean_squared_error: 1.1607 - val_loss: 5.6761 - val_y1_output_root_mean_squared_error: 1.2403 - val_y2_output_root_mean_squared_error: 2.0342
# Epoch 142/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2150 - y1_output_root_mean_squared_error: 0.6680 - y2_output_root_mean_squared_error: 1.3138 - val_loss: 2.9853 - val_y1_output_root_mean_squared_error: 0.8949 - val_y2_output_root_mean_squared_error: 1.4780
# Epoch 143/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1747 - y1_output_root_mean_squared_error: 0.7469 - y2_output_root_mean_squared_error: 1.2615 - val_loss: 6.9800 - val_y1_output_root_mean_squared_error: 1.4176 - val_y2_output_root_mean_squared_error: 2.2294
# Epoch 144/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9456 - y1_output_root_mean_squared_error: 0.8842 - y2_output_root_mean_squared_error: 1.4359 - val_loss: 9.8653 - val_y1_output_root_mean_squared_error: 1.2445 - val_y2_output_root_mean_squared_error: 2.8838
# Epoch 145/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3886 - y1_output_root_mean_squared_error: 0.8435 - y2_output_root_mean_squared_error: 1.5761 - val_loss: 4.7609 - val_y1_output_root_mean_squared_error: 0.7842 - val_y2_output_root_mean_squared_error: 2.0362
# Epoch 146/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8287 - y1_output_root_mean_squared_error: 0.5710 - y2_output_root_mean_squared_error: 1.2146 - val_loss: 2.0253 - val_y1_output_root_mean_squared_error: 0.5701 - val_y2_output_root_mean_squared_error: 1.3040
# Epoch 147/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0094 - y1_output_root_mean_squared_error: 0.6001 - y2_output_root_mean_squared_error: 1.2747 - val_loss: 1.9893 - val_y1_output_root_mean_squared_error: 0.5589 - val_y2_output_root_mean_squared_error: 1.2950
# Epoch 148/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1820 - y1_output_root_mean_squared_error: 0.5648 - y2_output_root_mean_squared_error: 0.9139 - val_loss: 2.3878 - val_y1_output_root_mean_squared_error: 0.5417 - val_y2_output_root_mean_squared_error: 1.4472
# Epoch 149/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2413 - y1_output_root_mean_squared_error: 0.7186 - y2_output_root_mean_squared_error: 1.2959 - val_loss: 2.4106 - val_y1_output_root_mean_squared_error: 0.5374 - val_y2_output_root_mean_squared_error: 1.4566
# Epoch 150/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1804 - y1_output_root_mean_squared_error: 0.5317 - y2_output_root_mean_squared_error: 0.9315 - val_loss: 1.9731 - val_y1_output_root_mean_squared_error: 0.6002 - val_y2_output_root_mean_squared_error: 1.2700
# Epoch 151/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3682 - y1_output_root_mean_squared_error: 0.5952 - y2_output_root_mean_squared_error: 1.0037 - val_loss: 16.5575 - val_y1_output_root_mean_squared_error: 1.2175 - val_y2_output_root_mean_squared_error: 3.8827
# Epoch 152/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4355 - y1_output_root_mean_squared_error: 0.7181 - y2_output_root_mean_squared_error: 1.3504 - val_loss: 2.4490 - val_y1_output_root_mean_squared_error: 0.7506 - val_y2_output_root_mean_squared_error: 1.3732
# Epoch 153/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5423 - y1_output_root_mean_squared_error: 0.6205 - y2_output_root_mean_squared_error: 1.0715 - val_loss: 4.0171 - val_y1_output_root_mean_squared_error: 0.7356 - val_y2_output_root_mean_squared_error: 1.8644
# Epoch 154/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3961 - y1_output_root_mean_squared_error: 0.6359 - y2_output_root_mean_squared_error: 1.3988 - val_loss: 1.8918 - val_y1_output_root_mean_squared_error: 0.5573 - val_y2_output_root_mean_squared_error: 1.2574
# Epoch 155/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7759 - y1_output_root_mean_squared_error: 0.7865 - y2_output_root_mean_squared_error: 1.4077 - val_loss: 10.8364 - val_y1_output_root_mean_squared_error: 1.1976 - val_y2_output_root_mean_squared_error: 3.0663
# Epoch 156/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8330 - y1_output_root_mean_squared_error: 0.6868 - y2_output_root_mean_squared_error: 1.4783 - val_loss: 2.0072 - val_y1_output_root_mean_squared_error: 0.6275 - val_y2_output_root_mean_squared_error: 1.2702
# Epoch 157/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5160 - y1_output_root_mean_squared_error: 0.6121 - y2_output_root_mean_squared_error: 1.0635 - val_loss: 7.9820 - val_y1_output_root_mean_squared_error: 1.3628 - val_y2_output_root_mean_squared_error: 2.4748
# Epoch 158/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9435 - y1_output_root_mean_squared_error: 0.6326 - y2_output_root_mean_squared_error: 1.1967 - val_loss: 5.3247 - val_y1_output_root_mean_squared_error: 1.1511 - val_y2_output_root_mean_squared_error: 1.9999
# Epoch 159/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4796 - y1_output_root_mean_squared_error: 0.7472 - y2_output_root_mean_squared_error: 1.3749 - val_loss: 1.9632 - val_y1_output_root_mean_squared_error: 0.5164 - val_y2_output_root_mean_squared_error: 1.3025
# Epoch 160/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5430 - y1_output_root_mean_squared_error: 0.5831 - y2_output_root_mean_squared_error: 1.0643 - val_loss: 4.3267 - val_y1_output_root_mean_squared_error: 0.8405 - val_y2_output_root_mean_squared_error: 1.9027
# Epoch 161/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2797 - y1_output_root_mean_squared_error: 0.8463 - y2_output_root_mean_squared_error: 1.5678 - val_loss: 2.6813 - val_y1_output_root_mean_squared_error: 0.6757 - val_y2_output_root_mean_squared_error: 1.4915
# Epoch 162/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1329 - y1_output_root_mean_squared_error: 0.6571 - y2_output_root_mean_squared_error: 1.3005 - val_loss: 2.0269 - val_y1_output_root_mean_squared_error: 0.5633 - val_y2_output_root_mean_squared_error: 1.3075
# Epoch 163/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1978 - y1_output_root_mean_squared_error: 0.5439 - y2_output_root_mean_squared_error: 0.9435 - val_loss: 1.9165 - val_y1_output_root_mean_squared_error: 0.5468 - val_y2_output_root_mean_squared_error: 1.2718
# Epoch 164/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2702 - y1_output_root_mean_squared_error: 0.4899 - y2_output_root_mean_squared_error: 1.0044 - val_loss: 1.9891 - val_y1_output_root_mean_squared_error: 0.5258 - val_y2_output_root_mean_squared_error: 1.3087
# Epoch 165/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.7769 - y1_output_root_mean_squared_error: 0.6558 - y2_output_root_mean_squared_error: 1.1563 - val_loss: 1.9065 - val_y1_output_root_mean_squared_error: 0.5228 - val_y2_output_root_mean_squared_error: 1.2779
# Epoch 166/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1503 - y1_output_root_mean_squared_error: 0.4667 - y2_output_root_mean_squared_error: 0.9600 - val_loss: 2.6918 - val_y1_output_root_mean_squared_error: 0.7668 - val_y2_output_root_mean_squared_error: 1.4505
# Epoch 167/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9820 - y1_output_root_mean_squared_error: 0.6155 - y2_output_root_mean_squared_error: 1.2495 - val_loss: 1.8998 - val_y1_output_root_mean_squared_error: 0.5923 - val_y2_output_root_mean_squared_error: 1.2446
# Epoch 168/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.2417 - y1_output_root_mean_squared_error: 0.5448 - y2_output_root_mean_squared_error: 0.9661 - val_loss: 2.8937 - val_y1_output_root_mean_squared_error: 0.8778 - val_y2_output_root_mean_squared_error: 1.4571
# Epoch 169/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.9469 - y1_output_root_mean_squared_error: 0.6833 - y2_output_root_mean_squared_error: 1.2076 - val_loss: 3.1707 - val_y1_output_root_mean_squared_error: 0.5981 - val_y2_output_root_mean_squared_error: 1.6772
# Epoch 170/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3646 - y1_output_root_mean_squared_error: 0.6102 - y2_output_root_mean_squared_error: 0.9951 - val_loss: 1.9816 - val_y1_output_root_mean_squared_error: 0.5623 - val_y2_output_root_mean_squared_error: 1.2905
# Epoch 171/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3086 - y1_output_root_mean_squared_error: 0.5153 - y2_output_root_mean_squared_error: 1.0163 - val_loss: 3.0196 - val_y1_output_root_mean_squared_error: 0.6962 - val_y2_output_root_mean_squared_error: 1.5921
# Epoch 172/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0921 - y1_output_root_mean_squared_error: 0.7911 - y2_output_root_mean_squared_error: 1.5137 - val_loss: 2.1325 - val_y1_output_root_mean_squared_error: 0.5724 - val_y2_output_root_mean_squared_error: 1.3434
# Epoch 173/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2338 - y1_output_root_mean_squared_error: 0.5199 - y2_output_root_mean_squared_error: 0.9794 - val_loss: 2.3125 - val_y1_output_root_mean_squared_error: 0.6653 - val_y2_output_root_mean_squared_error: 1.3674
# Epoch 174/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7530 - y1_output_root_mean_squared_error: 0.6694 - y2_output_root_mean_squared_error: 1.1275 - val_loss: 1.8784 - val_y1_output_root_mean_squared_error: 0.5168 - val_y2_output_root_mean_squared_error: 1.2694
# Epoch 175/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6937 - y1_output_root_mean_squared_error: 0.5616 - y2_output_root_mean_squared_error: 1.1620 - val_loss: 2.3039 - val_y1_output_root_mean_squared_error: 0.4974 - val_y2_output_root_mean_squared_error: 1.4340
# Epoch 176/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1014 - y1_output_root_mean_squared_error: 0.4631 - y2_output_root_mean_squared_error: 0.9349 - val_loss: 3.7431 - val_y1_output_root_mean_squared_error: 0.7855 - val_y2_output_root_mean_squared_error: 1.7680
# Epoch 177/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4494 - y1_output_root_mean_squared_error: 0.5122 - y2_output_root_mean_squared_error: 1.0790 - val_loss: 1.8187 - val_y1_output_root_mean_squared_error: 0.4911 - val_y2_output_root_mean_squared_error: 1.2560
# Epoch 178/500
# ...
# Epoch 442/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3532 - y1_output_root_mean_squared_error: 0.3245 - y2_output_root_mean_squared_error: 0.4964 - val_loss: 1.0054 - val_y1_output_root_mean_squared_error: 0.4241 - val_y2_output_root_mean_squared_error: 0.9086
# Epoch 443/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3862 - y1_output_root_mean_squared_error: 0.3108 - y2_output_root_mean_squared_error: 0.5359 - val_loss: 1.2573 - val_y1_output_root_mean_squared_error: 0.4623 - val_y2_output_root_mean_squared_error: 1.0216
# Epoch 444/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3842 - y1_output_root_mean_squared_error: 0.3257 - y2_output_root_mean_squared_error: 0.5252 - val_loss: 1.6755 - val_y1_output_root_mean_squared_error: 0.5962 - val_y2_output_root_mean_squared_error: 1.1489
# Epoch 445/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6142 - y1_output_root_mean_squared_error: 0.3966 - y2_output_root_mean_squared_error: 0.6633 - val_loss: 0.9280 - val_y1_output_root_mean_squared_error: 0.4079 - val_y2_output_root_mean_squared_error: 0.8727
# Epoch 446/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3271 - y1_output_root_mean_squared_error: 0.3198 - y2_output_root_mean_squared_error: 0.4726 - val_loss: 1.0141 - val_y1_output_root_mean_squared_error: 0.4188 - val_y2_output_root_mean_squared_error: 0.9158
# Epoch 447/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3018 - y1_output_root_mean_squared_error: 0.3121 - y2_output_root_mean_squared_error: 0.4503 - val_loss: 1.8447 - val_y1_output_root_mean_squared_error: 0.4055 - val_y2_output_root_mean_squared_error: 1.2963
# Epoch 448/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4232 - y1_output_root_mean_squared_error: 0.3341 - y2_output_root_mean_squared_error: 0.5560 - val_loss: 1.1577 - val_y1_output_root_mean_squared_error: 0.4165 - val_y2_output_root_mean_squared_error: 0.9921
# Epoch 449/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4853 - y1_output_root_mean_squared_error: 0.3416 - y2_output_root_mean_squared_error: 0.6027 - val_loss: 0.8905 - val_y1_output_root_mean_squared_error: 0.4055 - val_y2_output_root_mean_squared_error: 0.8521
# Epoch 450/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4126 - y1_output_root_mean_squared_error: 0.3268 - y2_output_root_mean_squared_error: 0.5479 - val_loss: 0.9071 - val_y1_output_root_mean_squared_error: 0.4057 - val_y2_output_root_mean_squared_error: 0.8617
# Epoch 451/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3180 - y1_output_root_mean_squared_error: 0.3302 - y2_output_root_mean_squared_error: 0.4505 - val_loss: 0.9260 - val_y1_output_root_mean_squared_error: 0.4396 - val_y2_output_root_mean_squared_error: 0.8560
# Epoch 452/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3430 - y1_output_root_mean_squared_error: 0.3097 - y2_output_root_mean_squared_error: 0.4942 - val_loss: 1.1253 - val_y1_output_root_mean_squared_error: 0.4684 - val_y2_output_root_mean_squared_error: 0.9517
# Epoch 453/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4630 - y1_output_root_mean_squared_error: 0.3920 - y2_output_root_mean_squared_error: 0.5533 - val_loss: 1.5221 - val_y1_output_root_mean_squared_error: 0.4602 - val_y2_output_root_mean_squared_error: 1.1447
# Epoch 454/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3981 - y1_output_root_mean_squared_error: 0.3311 - y2_output_root_mean_squared_error: 0.5344 - val_loss: 0.9592 - val_y1_output_root_mean_squared_error: 0.3969 - val_y2_output_root_mean_squared_error: 0.8954
# Epoch 455/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4368 - y1_output_root_mean_squared_error: 0.3432 - y2_output_root_mean_squared_error: 0.5614 - val_loss: 1.0464 - val_y1_output_root_mean_squared_error: 0.4119 - val_y2_output_root_mean_squared_error: 0.9363
# Epoch 456/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3476 - y1_output_root_mean_squared_error: 0.3222 - y2_output_root_mean_squared_error: 0.4895 - val_loss: 1.5540 - val_y1_output_root_mean_squared_error: 0.4422 - val_y2_output_root_mean_squared_error: 1.1655
# Epoch 457/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3972 - y1_output_root_mean_squared_error: 0.3198 - y2_output_root_mean_squared_error: 0.5335 - val_loss: 0.9799 - val_y1_output_root_mean_squared_error: 0.4149 - val_y2_output_root_mean_squared_error: 0.8988
# Epoch 458/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3512 - y1_output_root_mean_squared_error: 0.3401 - y2_output_root_mean_squared_error: 0.4827 - val_loss: 0.8664 - val_y1_output_root_mean_squared_error: 0.4143 - val_y2_output_root_mean_squared_error: 0.8335
# Epoch 459/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4168 - y1_output_root_mean_squared_error: 0.3305 - y2_output_root_mean_squared_error: 0.5531 - val_loss: 1.5068 - val_y1_output_root_mean_squared_error: 0.5545 - val_y2_output_root_mean_squared_error: 1.0951
# Epoch 460/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6368 - y1_output_root_mean_squared_error: 0.4269 - y2_output_root_mean_squared_error: 0.6676 - val_loss: 0.9040 - val_y1_output_root_mean_squared_error: 0.3999 - val_y2_output_root_mean_squared_error: 0.8626
# Epoch 461/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6310 - y1_output_root_mean_squared_error: 0.4031 - y2_output_root_mean_squared_error: 0.6767 - val_loss: 1.1360 - val_y1_output_root_mean_squared_error: 0.4703 - val_y2_output_root_mean_squared_error: 0.9565
# Epoch 462/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4982 - y1_output_root_mean_squared_error: 0.3592 - y2_output_root_mean_squared_error: 0.6025 - val_loss: 0.8749 - val_y1_output_root_mean_squared_error: 0.4219 - val_y2_output_root_mean_squared_error: 0.8348
# Epoch 463/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4168 - y1_output_root_mean_squared_error: 0.3729 - y2_output_root_mean_squared_error: 0.5209 - val_loss: 1.4234 - val_y1_output_root_mean_squared_error: 0.5205 - val_y2_output_root_mean_squared_error: 1.0735
# Epoch 464/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3584 - y1_output_root_mean_squared_error: 0.3308 - y2_output_root_mean_squared_error: 0.4962 - val_loss: 0.9105 - val_y1_output_root_mean_squared_error: 0.3995 - val_y2_output_root_mean_squared_error: 0.8665
# Epoch 465/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4219 - y1_output_root_mean_squared_error: 0.3436 - y2_output_root_mean_squared_error: 0.5402 - val_loss: 1.0187 - val_y1_output_root_mean_squared_error: 0.4484 - val_y2_output_root_mean_squared_error: 0.9042
# Epoch 466/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3361 - y1_output_root_mean_squared_error: 0.3473 - y2_output_root_mean_squared_error: 0.4601 - val_loss: 1.0439 - val_y1_output_root_mean_squared_error: 0.3893 - val_y2_output_root_mean_squared_error: 0.9446
# Epoch 467/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3301 - y1_output_root_mean_squared_error: 0.3229 - y2_output_root_mean_squared_error: 0.4725 - val_loss: 0.9055 - val_y1_output_root_mean_squared_error: 0.4228 - val_y2_output_root_mean_squared_error: 0.8525
# Epoch 468/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4443 - y1_output_root_mean_squared_error: 0.3636 - y2_output_root_mean_squared_error: 0.5378 - val_loss: 1.1165 - val_y1_output_root_mean_squared_error: 0.4226 - val_y2_output_root_mean_squared_error: 0.9685
# Epoch 469/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2764 - y1_output_root_mean_squared_error: 0.3141 - y2_output_root_mean_squared_error: 0.4207 - val_loss: 0.9129 - val_y1_output_root_mean_squared_error: 0.4121 - val_y2_output_root_mean_squared_error: 0.8620
# Epoch 470/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3587 - y1_output_root_mean_squared_error: 0.3047 - y2_output_root_mean_squared_error: 0.5145 - val_loss: 1.0343 - val_y1_output_root_mean_squared_error: 0.4360 - val_y2_output_root_mean_squared_error: 0.9188
# Epoch 471/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5400 - y1_output_root_mean_squared_error: 0.3704 - y2_output_root_mean_squared_error: 0.6300 - val_loss: 0.8998 - val_y1_output_root_mean_squared_error: 0.4239 - val_y2_output_root_mean_squared_error: 0.8486
# Epoch 472/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3714 - y1_output_root_mean_squared_error: 0.3605 - y2_output_root_mean_squared_error: 0.4844 - val_loss: 1.0367 - val_y1_output_root_mean_squared_error: 0.4163 - val_y2_output_root_mean_squared_error: 0.9292
# Epoch 473/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5272 - y1_output_root_mean_squared_error: 0.3717 - y2_output_root_mean_squared_error: 0.5973 - val_loss: 1.0201 - val_y1_output_root_mean_squared_error: 0.4855 - val_y2_output_root_mean_squared_error: 0.8857
# Epoch 474/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3351 - y1_output_root_mean_squared_error: 0.3226 - y2_output_root_mean_squared_error: 0.4769 - val_loss: 1.1035 - val_y1_output_root_mean_squared_error: 0.4223 - val_y2_output_root_mean_squared_error: 0.9619
# Epoch 475/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3304 - y1_output_root_mean_squared_error: 0.3298 - y2_output_root_mean_squared_error: 0.4689 - val_loss: 0.9369 - val_y1_output_root_mean_squared_error: 0.4100 - val_y2_output_root_mean_squared_error: 0.8768
# Epoch 476/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3074 - y1_output_root_mean_squared_error: 0.3266 - y2_output_root_mean_squared_error: 0.4449 - val_loss: 0.9723 - val_y1_output_root_mean_squared_error: 0.4002 - val_y2_output_root_mean_squared_error: 0.9012
# Epoch 477/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2833 - y1_output_root_mean_squared_error: 0.3012 - y2_output_root_mean_squared_error: 0.4372 - val_loss: 1.3654 - val_y1_output_root_mean_squared_error: 0.4868 - val_y2_output_root_mean_squared_error: 1.0623
# Epoch 478/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4301 - y1_output_root_mean_squared_error: 0.3192 - y2_output_root_mean_squared_error: 0.5673 - val_loss: 1.1096 - val_y1_output_root_mean_squared_error: 0.4946 - val_y2_output_root_mean_squared_error: 0.9300
# Epoch 479/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3316 - y1_output_root_mean_squared_error: 0.3287 - y2_output_root_mean_squared_error: 0.4715 - val_loss: 0.8942 - val_y1_output_root_mean_squared_error: 0.4174 - val_y2_output_root_mean_squared_error: 0.8485
# Epoch 480/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4054 - y1_output_root_mean_squared_error: 0.3534 - y2_output_root_mean_squared_error: 0.5277 - val_loss: 0.9976 - val_y1_output_root_mean_squared_error: 0.4316 - val_y2_output_root_mean_squared_error: 0.9008
# Epoch 481/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3108 - y1_output_root_mean_squared_error: 0.3240 - y2_output_root_mean_squared_error: 0.4526 - val_loss: 0.9431 - val_y1_output_root_mean_squared_error: 0.4456 - val_y2_output_root_mean_squared_error: 0.8629
# Epoch 482/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3558 - y1_output_root_mean_squared_error: 0.3022 - y2_output_root_mean_squared_error: 0.5132 - val_loss: 0.8829 - val_y1_output_root_mean_squared_error: 0.3771 - val_y2_output_root_mean_squared_error: 0.8607
# Epoch 483/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2912 - y1_output_root_mean_squared_error: 0.2757 - y2_output_root_mean_squared_error: 0.4619 - val_loss: 0.8983 - val_y1_output_root_mean_squared_error: 0.3947 - val_y2_output_root_mean_squared_error: 0.8617
# Epoch 484/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3250 - y1_output_root_mean_squared_error: 0.3265 - y2_output_root_mean_squared_error: 0.4657 - val_loss: 1.3000 - val_y1_output_root_mean_squared_error: 0.5275 - val_y2_output_root_mean_squared_error: 1.0108
# Epoch 485/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4074 - y1_output_root_mean_squared_error: 0.3493 - y2_output_root_mean_squared_error: 0.5320 - val_loss: 1.0315 - val_y1_output_root_mean_squared_error: 0.4649 - val_y2_output_root_mean_squared_error: 0.9030
# Epoch 486/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4503 - y1_output_root_mean_squared_error: 0.3705 - y2_output_root_mean_squared_error: 0.5499 - val_loss: 0.9665 - val_y1_output_root_mean_squared_error: 0.4096 - val_y2_output_root_mean_squared_error: 0.8937
# Epoch 487/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3441 - y1_output_root_mean_squared_error: 0.2920 - y2_output_root_mean_squared_error: 0.5047 - val_loss: 1.1551 - val_y1_output_root_mean_squared_error: 0.4527 - val_y2_output_root_mean_squared_error: 0.9748
# Epoch 488/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3217 - y1_output_root_mean_squared_error: 0.3112 - y2_output_root_mean_squared_error: 0.4729 - val_loss: 0.9056 - val_y1_output_root_mean_squared_error: 0.3994 - val_y2_output_root_mean_squared_error: 0.8638
# Epoch 489/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2596 - y1_output_root_mean_squared_error: 0.2908 - y2_output_root_mean_squared_error: 0.4170 - val_loss: 3.6462 - val_y1_output_root_mean_squared_error: 0.9417 - val_y2_output_root_mean_squared_error: 1.6612
# Epoch 490/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6599 - y1_output_root_mean_squared_error: 0.4641 - y2_output_root_mean_squared_error: 0.6557 - val_loss: 0.8869 - val_y1_output_root_mean_squared_error: 0.4137 - val_y2_output_root_mean_squared_error: 0.8461
# Epoch 491/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2490 - y1_output_root_mean_squared_error: 0.2951 - y2_output_root_mean_squared_error: 0.4001 - val_loss: 1.0038 - val_y1_output_root_mean_squared_error: 0.4072 - val_y2_output_root_mean_squared_error: 0.9154
# Epoch 492/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2731 - y1_output_root_mean_squared_error: 0.3082 - y2_output_root_mean_squared_error: 0.4212 - val_loss: 0.9040 - val_y1_output_root_mean_squared_error: 0.3848 - val_y2_output_root_mean_squared_error: 0.8694
# Epoch 493/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5951 - y1_output_root_mean_squared_error: 0.3680 - y2_output_root_mean_squared_error: 0.6553 - val_loss: 1.8949 - val_y1_output_root_mean_squared_error: 0.6755 - val_y2_output_root_mean_squared_error: 1.1994
# Epoch 494/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2236 - y1_output_root_mean_squared_error: 0.5873 - y2_output_root_mean_squared_error: 0.8976 - val_loss: 0.9191 - val_y1_output_root_mean_squared_error: 0.4146 - val_y2_output_root_mean_squared_error: 0.8644
# Epoch 495/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3650 - y1_output_root_mean_squared_error: 0.3419 - y2_output_root_mean_squared_error: 0.4937 - val_loss: 1.0297 - val_y1_output_root_mean_squared_error: 0.3898 - val_y2_output_root_mean_squared_error: 0.9368
# Epoch 496/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2643 - y1_output_root_mean_squared_error: 0.2965 - y2_output_root_mean_squared_error: 0.4172 - val_loss: 1.1043 - val_y1_output_root_mean_squared_error: 0.4536 - val_y2_output_root_mean_squared_error: 0.9479
# Epoch 497/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4035 - y1_output_root_mean_squared_error: 0.3073 - y2_output_root_mean_squared_error: 0.5483 - val_loss: 1.1357 - val_y1_output_root_mean_squared_error: 0.5216 - val_y2_output_root_mean_squared_error: 0.9293
# Epoch 498/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3196 - y1_output_root_mean_squared_error: 0.3173 - y2_output_root_mean_squared_error: 0.4656 - val_loss: 0.9033 - val_y1_output_root_mean_squared_error: 0.3927 - val_y2_output_root_mean_squared_error: 0.8655
# Epoch 499/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3389 - y1_output_root_mean_squared_error: 0.3121 - y2_output_root_mean_squared_error: 0.4902 - val_loss: 0.8828 - val_y1_output_root_mean_squared_error: 0.3996 - val_y2_output_root_mean_squared_error: 0.8504
# Epoch 500/500
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3019 - y1_output_root_mean_squared_error: 0.2966 - y2_output_root_mean_squared_error: 0.4614 - val_loss: 1.0591 - val_y1_output_root_mean_squared_error: 0.4188 - val_y2_output_root_mean_squared_error: 0.9401

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Evaluate the model
results = model.evaluate(x=norm_test_X, y={'y1_output': test_Y[0], 'y2_output': test_Y[1]})

# Print the results
print("Results:", results)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9935 - y1_output_root_mean_squared_error: 0.4241 - y2_output_root_mean_squared_error: 0.9000
# Results: [1.0591398477554321, 0.4188246726989746, 0.9400668144226074]

# %%
if len(results) == 5:
    loss, Y1_loss, Y2_loss, Y1_mse, Y2_mse = results
    print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_mse, Y2_loss, Y2_mse))
else:
    print("Unexpected number of results returned:", results)
# Out:
# Unexpected number of results returned: [1.0591398477554321, 0.4188246726989746, 0.9400668144226074]

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
